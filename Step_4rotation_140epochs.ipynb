# %% [markdown]
# # Improved Regularization of Convolutional Neural Networks (Step-4rotation-140epochs)

# %% [markdown]
# ## 1. Resnet-20

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

# %%
def _weights_init(m):
    """
        Initialization of CNN weights
    """
    classname = m.__class__.__name__
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight)

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet20_rot(nn.Module):
    def __init__(self):
        super(ResNet20_rot, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)

        self.layer1 = self.blocks(16, 16, 3, stride=1)
        self.layer2 = self.blocks(16, 32, 3, stride=2)
        self.layer3 = self.blocks(32, 64, 3, stride=2)
        self.fc = nn.Linear(64, 10)
        self.fc_rotation = nn.Linear(64, 4) #rotation
        self.apply(_weights_init)

    def blocks(self, in_channels, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for i in strides:
            layers.append(ResidualBlock(in_channels, out_channels, i))
            in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1)
        out_classification = self.fc(out)
        out_rotation = self.fc_rotation(out) #rotation
        return out_classification, out_rotation

# %% [markdown]
# ## 2. Data Processing

# %%
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import Dataset, DataLoader

class CIFAR10WithRotation(Dataset):
    def __init__(self, root, train, transform):
        self.dataset = torchvision.datasets.CIFAR10(root=root, train=train, download=True, transform=transform)
        self.rotations = [0, 90, 180, 270]

    def __len__(self):
        return len(self.dataset) * len(self.rotations)

    def __getitem__(self, idx):
        image, label = self.dataset[idx % len(self.dataset)]
        rotation_idx = idx // len(self.dataset)
        rotation_angle = self.rotations[rotation_idx]
        rotated_image = transforms.functional.rotate(image, rotation_angle)
        return rotated_image, label, rotation_idx


normalize = transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],
                                     std=[0.2023, 0.1994, 0.2010])


train_loader = DataLoader(
        CIFAR10WithRotation(root='./data', train=True, transform=transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.RandomCrop(32, 4),
            transforms.ToTensor(),
            normalize,
        ])),
        batch_size=128, shuffle=True,
        num_workers=4, pin_memory=True)

val_loader = DataLoader(
        datasets.CIFAR10(root='./data', train=False, transform=transforms.Compose([
            transforms.ToTensor(),
            normalize,
        ]), download=True),
        batch_size=128, shuffle=False,
        num_workers=4, pin_memory=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:14<00:00, 11393881.94it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ## 3. Model Training

# %%
import torch.optim as optim

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = ResNet20_rot().to(device)

INITIAL_LR = 0.1
MOMENTUM = 0.9
REG = 1e-4

criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)

# %%
import os
EPOCHS = 140
DECAY_EPOCHS = [30,60,100]#decay epoch change according to essay
DECAY = 0.2
LAMBDA = 0.75 #rotation
CHECKPOINT_FOLDER = "./saved_model"

best_val_acc = 0
best_val_acc_loss = 0
train_accs=[]
train_losses=[]
val_accs=[]
val_losses=[]
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
    if i in DECAY_EPOCHS:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)

    model.train()
    print("Epoch %d:" %i)
    total_examples = 0
    correct_examples = 0
    train_loss = 0

    for batch_idx, (inputs, targets, rotations) in enumerate(train_loader):
        inputs, targets, rotations = inputs.to(device), targets.to(device), rotations.to(device) #rotation

        outputs, rotation_outputs = model(inputs)
        loss = criterion(outputs, targets) + LAMBDA * criterion(rotation_outputs, rotations) if i>=100 else criterion(rotation_outputs, rotations)#rotation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total_examples += targets.size(0)
        correct_examples += predicted.eq(targets).sum().item()


    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
    train_accs.append(avg_acc)
    train_losses.append(avg_loss)


    model.eval()
    total_examples = 0
    correct_examples = 0

    val_loss = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs, _ = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item()
            _, predicted = outputs.max(1)
            total_examples += targets.size(0)
            correct_examples += predicted.eq(targets).sum().item()

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    val_accs.append(avg_acc)
    val_losses.append(avg_loss)

    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        best_val_acc_loss = avg_loss
        if not os.path.exists(CHECKPOINT_FOLDER):
            os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': model.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'rotation.pth'))

    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f} with loss: {best_val_acc_loss:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.0412, Training accuracy: 0.1002
# Validation loss: 2.5278, Validation accuracy: 0.0611
# Saving ...
#
# Epoch 1:
# Training loss: 0.8586, Training accuracy: 0.0911
# Validation loss: 2.4283, Validation accuracy: 0.0517
#
# Epoch 2:
# Training loss: 0.7281, Training accuracy: 0.0822
# Validation loss: 2.4594, Validation accuracy: 0.0453
#
# Epoch 3:
# Training loss: 0.6413, Training accuracy: 0.0735
# Validation loss: 2.4086, Validation accuracy: 0.0406
#
# Epoch 4:
# Training loss: 0.5823, Training accuracy: 0.0726
# Validation loss: 2.4796, Validation accuracy: 0.0459
#
# Epoch 5:
# Training loss: 0.5387, Training accuracy: 0.0700
# Validation loss: 2.5160, Validation accuracy: 0.0498
#
# Epoch 6:
# Training loss: 0.5051, Training accuracy: 0.0686
# Validation loss: 2.5718, Validation accuracy: 0.0693
# Saving ...
#
# Epoch 7:
# Training loss: 0.4800, Training accuracy: 0.0677
# Validation loss: 2.5479, Validation accuracy: 0.0593
#
# Epoch 8:
# Training loss: 0.4603, Training accuracy: 0.0711
# Validation loss: 2.4391, Validation accuracy: 0.0835
# Saving ...
#
# Epoch 9:
# Training loss: 0.4460, Training accuracy: 0.0656
# Validation loss: 2.4955, Validation accuracy: 0.0513
#
# Epoch 10:
# Training loss: 0.4321, Training accuracy: 0.0638
# Validation loss: 2.4731, Validation accuracy: 0.0713
#
# Epoch 11:
# Training loss: 0.4213, Training accuracy: 0.0665
# Validation loss: 2.5330, Validation accuracy: 0.0388
#
# Epoch 12:
# Training loss: 0.4137, Training accuracy: 0.0652
# Validation loss: 2.4974, Validation accuracy: 0.0554
#
# Epoch 13:
# Training loss: 0.4044, Training accuracy: 0.0671
# Validation loss: 2.5632, Validation accuracy: 0.0385
#
# Epoch 14:
# Training loss: 0.3984, Training accuracy: 0.0656
# Validation loss: 2.4872, Validation accuracy: 0.0259
#
# Epoch 15:
# Training loss: 0.3941, Training accuracy: 0.0639
# Validation loss: 2.5101, Validation accuracy: 0.0464
#
# Epoch 16:
# Training loss: 0.3893, Training accuracy: 0.0642
# Validation loss: 2.4837, Validation accuracy: 0.0468
#
# Epoch 17:
# Training loss: 0.3842, Training accuracy: 0.0630
# Validation loss: 2.4950, Validation accuracy: 0.0437
#
# Epoch 18:
# Training loss: 0.3815, Training accuracy: 0.0633
# Validation loss: 2.5061, Validation accuracy: 0.0495
#
# Epoch 19:
# Training loss: 0.3774, Training accuracy: 0.0641
# Validation loss: 2.5152, Validation accuracy: 0.0228
#
# Epoch 20:
# Training loss: 0.3748, Training accuracy: 0.0649
# Validation loss: 2.4878, Validation accuracy: 0.0399
#
# Epoch 21:
# Training loss: 0.3711, Training accuracy: 0.0665
# Validation loss: 2.5018, Validation accuracy: 0.0277
#
# Epoch 22:
# Training loss: 0.3665, Training accuracy: 0.0670
# Validation loss: 2.5422, Validation accuracy: 0.0230
#
# Epoch 23:
# Training loss: 0.3663, Training accuracy: 0.0629
# Validation loss: 2.5057, Validation accuracy: 0.0558
#
# Epoch 24:
# Training loss: 0.3634, Training accuracy: 0.0637
# Validation loss: 2.4574, Validation accuracy: 0.0328
#
# Epoch 25:
# Training loss: 0.3598, Training accuracy: 0.0635
# Validation loss: 2.5476, Validation accuracy: 0.0342
#
# Epoch 26:
# Training loss: 0.3567, Training accuracy: 0.0650
# Validation loss: 2.4849, Validation accuracy: 0.0260
#
# Epoch 27:
# Training loss: 0.3558, Training accuracy: 0.0643
# Validation loss: 2.4717, Validation accuracy: 0.0297
#
# Epoch 28:
# Training loss: 0.3554, Training accuracy: 0.0625
# Validation loss: 2.5204, Validation accuracy: 0.0428
#
# Epoch 29:
# Training loss: 0.3528, Training accuracy: 0.0614
# Validation loss: 2.4843, Validation accuracy: 0.0388
#
# Current learning rate has decayed to 0.020000
# Epoch 30:
# Training loss: 0.2568, Training accuracy: 0.0596
# Validation loss: 2.5102, Validation accuracy: 0.0332
#
# Epoch 31:
# Training loss: 0.2382, Training accuracy: 0.0607
# Validation loss: 2.5373, Validation accuracy: 0.0334
#
# Epoch 32:
# Training loss: 0.2298, Training accuracy: 0.0606
# Validation loss: 2.5278, Validation accuracy: 0.0439
#
# Epoch 33:
# Training loss: 0.2282, Training accuracy: 0.0615
# Validation loss: 2.5554, Validation accuracy: 0.0292
#
# Epoch 34:
# Training loss: 0.2271, Training accuracy: 0.0606
# Validation loss: 2.5313, Validation accuracy: 0.0414
#
# Epoch 35:
# Training loss: 0.2234, Training accuracy: 0.0602
# Validation loss: 2.5499, Validation accuracy: 0.0208
#
# Epoch 36:
# Training loss: 0.2227, Training accuracy: 0.0597
# Validation loss: 2.5436, Validation accuracy: 0.0292
#
# Epoch 37:
# Training loss: 0.2216, Training accuracy: 0.0610
# Validation loss: 2.5394, Validation accuracy: 0.0278
#
# Epoch 38:
# Training loss: 0.2205, Training accuracy: 0.0581
# Validation loss: 2.5686, Validation accuracy: 0.0239
#
# Epoch 39:
# Training loss: 0.2212, Training accuracy: 0.0568
# Validation loss: 2.5357, Validation accuracy: 0.0241
#
# Epoch 40:
# Training loss: 0.2205, Training accuracy: 0.0570
# Validation loss: 2.5519, Validation accuracy: 0.0207
#
# Epoch 41:
# Training loss: 0.2201, Training accuracy: 0.0573
# Validation loss: 2.5261, Validation accuracy: 0.0252
#
# Epoch 42:
# Training loss: 0.2222, Training accuracy: 0.0566
# Validation loss: 2.5769, Validation accuracy: 0.0169
#
# Epoch 43:
# Training loss: 0.2211, Training accuracy: 0.0579
# Validation loss: 2.5304, Validation accuracy: 0.0280
#
# Epoch 44:
# Training loss: 0.2219, Training accuracy: 0.0571
# Validation loss: 2.5650, Validation accuracy: 0.0183
#
# Epoch 45:
# Training loss: 0.2209, Training accuracy: 0.0558
# Validation loss: 2.5317, Validation accuracy: 0.0290
#
# Epoch 46:
# Training loss: 0.2212, Training accuracy: 0.0573
# Validation loss: 2.5336, Validation accuracy: 0.0417
#
# Epoch 47:
# Training loss: 0.2203, Training accuracy: 0.0558
# Validation loss: 2.5316, Validation accuracy: 0.0229
#
# Epoch 48:
# Training loss: 0.2227, Training accuracy: 0.0565
# Validation loss: 2.6077, Validation accuracy: 0.0166
#
# Epoch 49:
# Training loss: 0.2212, Training accuracy: 0.0583
# Validation loss: 2.5279, Validation accuracy: 0.0338
#
# Epoch 50:
# Training loss: 0.2202, Training accuracy: 0.0579
# Validation loss: 2.5797, Validation accuracy: 0.0316
#
# Epoch 51:
# Training loss: 0.2222, Training accuracy: 0.0581
# Validation loss: 2.5389, Validation accuracy: 0.0307
#
# Epoch 52:
# Training loss: 0.2209, Training accuracy: 0.0574
# Validation loss: 2.5456, Validation accuracy: 0.0228
#
# Epoch 53:
# Training loss: 0.2202, Training accuracy: 0.0580
# Validation loss: 2.5740, Validation accuracy: 0.0183
#
# Epoch 54:
# Training loss: 0.2204, Training accuracy: 0.0592
# Validation loss: 2.5125, Validation accuracy: 0.0246
#
# Epoch 55:
# Training loss: 0.2189, Training accuracy: 0.0600
# Validation loss: 2.5833, Validation accuracy: 0.0240
#
# Epoch 56:
# Training loss: 0.2186, Training accuracy: 0.0599
# Validation loss: 2.5367, Validation accuracy: 0.0223
#
# Epoch 57:
# Training loss: 0.2199, Training accuracy: 0.0592
# Validation loss: 2.5044, Validation accuracy: 0.0320
#
# Epoch 58:
# Training loss: 0.2200, Training accuracy: 0.0577
# Validation loss: 2.5429, Validation accuracy: 0.0228
#
# Epoch 59:
# Training loss: 0.2190, Training accuracy: 0.0592
# Validation loss: 2.5554, Validation accuracy: 0.0209
#
# Current learning rate has decayed to 0.004000
# Epoch 60:
# Training loss: 0.1683, Training accuracy: 0.0583
# Validation loss: 2.5548, Validation accuracy: 0.0248
#
# Epoch 61:
# Training loss: 0.1559, Training accuracy: 0.0599
# Validation loss: 2.5714, Validation accuracy: 0.0224
#
# Epoch 62:
# Training loss: 0.1514, Training accuracy: 0.0601
# Validation loss: 2.5925, Validation accuracy: 0.0222
#
# Epoch 63:
# Training loss: 0.1486, Training accuracy: 0.0601
# Validation loss: 2.5895, Validation accuracy: 0.0251
#
# Epoch 64:
# Training loss: 0.1457, Training accuracy: 0.0610
# Validation loss: 2.5756, Validation accuracy: 0.0266
#
# Epoch 65:
# Training loss: 0.1428, Training accuracy: 0.0602
# Validation loss: 2.5945, Validation accuracy: 0.0248
#
# Epoch 66:
# Training loss: 0.1418, Training accuracy: 0.0612
# Validation loss: 2.6008, Validation accuracy: 0.0272
#
# Epoch 67:
# Training loss: 0.1421, Training accuracy: 0.0608
# Validation loss: 2.5761, Validation accuracy: 0.0272
#
# Epoch 68:
# Training loss: 0.1409, Training accuracy: 0.0615
# Validation loss: 2.5900, Validation accuracy: 0.0271
#
# Epoch 69:
# Training loss: 0.1389, Training accuracy: 0.0624
# Validation loss: 2.5865, Validation accuracy: 0.0302
#
# Epoch 70:
# Training loss: 0.1370, Training accuracy: 0.0623
# Validation loss: 2.5854, Validation accuracy: 0.0281
#
# Epoch 71:
# Training loss: 0.1364, Training accuracy: 0.0622
# Validation loss: 2.5990, Validation accuracy: 0.0283
#
# Epoch 72:
# Training loss: 0.1354, Training accuracy: 0.0623
# Validation loss: 2.5967, Validation accuracy: 0.0264
#
# Epoch 73:
# Training loss: 0.1348, Training accuracy: 0.0620
# Validation loss: 2.5755, Validation accuracy: 0.0373
#
# Epoch 74:
# Training loss: 0.1336, Training accuracy: 0.0620
# Validation loss: 2.5927, Validation accuracy: 0.0306
#
# Epoch 75:
# Training loss: 0.1338, Training accuracy: 0.0617
# Validation loss: 2.6137, Validation accuracy: 0.0276
#
# Epoch 76:
# Training loss: 0.1324, Training accuracy: 0.0622
# Validation loss: 2.5964, Validation accuracy: 0.0284
#
# Epoch 77:
# Training loss: 0.1330, Training accuracy: 0.0612
# Validation loss: 2.5951, Validation accuracy: 0.0262
#
# Epoch 78:
# Training loss: 0.1331, Training accuracy: 0.0629
# Validation loss: 2.5774, Validation accuracy: 0.0291
#
# Epoch 79:
# Training loss: 0.1323, Training accuracy: 0.0622
# Validation loss: 2.5933, Validation accuracy: 0.0318
#
# Epoch 80:
# Training loss: 0.1297, Training accuracy: 0.0621
# Validation loss: 2.6013, Validation accuracy: 0.0287
#
# Epoch 81:
# Training loss: 0.1307, Training accuracy: 0.0625
# Validation loss: 2.5903, Validation accuracy: 0.0387
#
# Epoch 82:
# Training loss: 0.1300, Training accuracy: 0.0642
# Validation loss: 2.5994, Validation accuracy: 0.0354
#
# Epoch 83:
# Training loss: 0.1300, Training accuracy: 0.0641
# Validation loss: 2.5931, Validation accuracy: 0.0373
#
# Epoch 84:
# Training loss: 0.1307, Training accuracy: 0.0629
# Validation loss: 2.5946, Validation accuracy: 0.0334
#
# Epoch 85:
# Training loss: 0.1287, Training accuracy: 0.0635
# Validation loss: 2.5996, Validation accuracy: 0.0333
#
# Epoch 86:
# Training loss: 0.1304, Training accuracy: 0.0627
# Validation loss: 2.5951, Validation accuracy: 0.0298
#
# Epoch 87:
# Training loss: 0.1290, Training accuracy: 0.0648
# Validation loss: 2.5930, Validation accuracy: 0.0274
#
# Epoch 88:
# Training loss: 0.1270, Training accuracy: 0.0633
# Validation loss: 2.5888, Validation accuracy: 0.0301
#
# Epoch 89:
# Training loss: 0.1284, Training accuracy: 0.0634
# Validation loss: 2.6081, Validation accuracy: 0.0288
#
# Epoch 90:
# Training loss: 0.1281, Training accuracy: 0.0624
# Validation loss: 2.6066, Validation accuracy: 0.0289
#
# Epoch 91:
# Training loss: 0.1277, Training accuracy: 0.0641
# Validation loss: 2.5843, Validation accuracy: 0.0289
#
# Epoch 92:
# Training loss: 0.1276, Training accuracy: 0.0646
# Validation loss: 2.6241, Validation accuracy: 0.0308
#
# Epoch 93:
# Training loss: 0.1273, Training accuracy: 0.0663
# Validation loss: 2.6009, Validation accuracy: 0.0294
#
# Epoch 94:
# Training loss: 0.1275, Training accuracy: 0.0660
# Validation loss: 2.6245, Validation accuracy: 0.0334
#
# Epoch 95:
# Training loss: 0.1287, Training accuracy: 0.0664
# Validation loss: 2.5725, Validation accuracy: 0.0403
#
# Epoch 96:
# Training loss: 0.1269, Training accuracy: 0.0648
# Validation loss: 2.6047, Validation accuracy: 0.0389
#
# Epoch 97:
# Training loss: 0.1265, Training accuracy: 0.0646
# Validation loss: 2.5871, Validation accuracy: 0.0351
#
# Epoch 98:
# Training loss: 0.1260, Training accuracy: 0.0642
# Validation loss: 2.6127, Validation accuracy: 0.0298
#
# Epoch 99:
# Training loss: 0.1274, Training accuracy: 0.0650
# Validation loss: 2.5989, Validation accuracy: 0.0371
#
# Current learning rate has decayed to 0.000800
# Epoch 100:
# Training loss: 1.5788, Training accuracy: 0.5085
# Validation loss: 1.0014, Validation accuracy: 0.6388
# Saving ...
#
# Epoch 101:
# Training loss: 1.0750, Training accuracy: 0.6682
# Validation loss: 0.8333, Validation accuracy: 0.7033
# Saving ...
#
# Epoch 102:
# Training loss: 0.9408, Training accuracy: 0.7130
# Validation loss: 0.7498, Validation accuracy: 0.7351
# Saving ...
#
# Epoch 103:
# Training loss: 0.8625, Training accuracy: 0.7387
# Validation loss: 0.7021, Validation accuracy: 0.7514
# Saving ...
#
# Epoch 104:
# Training loss: 0.8158, Training accuracy: 0.7554
# Validation loss: 0.6644, Validation accuracy: 0.7652
# Saving ...
#
# Epoch 105:
# Training loss: 0.7784, Training accuracy: 0.7684
# Validation loss: 0.6455, Validation accuracy: 0.7728
# Saving ...
#
# Epoch 106:
# Training loss: 0.7529, Training accuracy: 0.7775
# Validation loss: 0.6207, Validation accuracy: 0.7820
# Saving ...
#
# Epoch 107:
# Training loss: 0.7289, Training accuracy: 0.7857
# Validation loss: 0.5993, Validation accuracy: 0.7911
# Saving ...
#
# Epoch 108:
# Training loss: 0.7089, Training accuracy: 0.7928
# Validation loss: 0.5925, Validation accuracy: 0.7934
# Saving ...
#
# Epoch 109:
# Training loss: 0.6925, Training accuracy: 0.7986
# Validation loss: 0.5840, Validation accuracy: 0.7990
# Saving ...
#
# Epoch 110:
# Training loss: 0.6773, Training accuracy: 0.8036
# Validation loss: 0.5649, Validation accuracy: 0.8039
# Saving ...
#
# Epoch 111:
# Training loss: 0.6663, Training accuracy: 0.8077
# Validation loss: 0.5574, Validation accuracy: 0.8090
# Saving ...
#
# Epoch 112:
# Training loss: 0.6546, Training accuracy: 0.8125
# Validation loss: 0.5516, Validation accuracy: 0.8086
#
# Epoch 113:
# Training loss: 0.6437, Training accuracy: 0.8156
# Validation loss: 0.5457, Validation accuracy: 0.8115
# Saving ...
#
# Epoch 114:
# Training loss: 0.6340, Training accuracy: 0.8192
# Validation loss: 0.5317, Validation accuracy: 0.8159
# Saving ...
#
# Epoch 115:
# Training loss: 0.6271, Training accuracy: 0.8218
# Validation loss: 0.5317, Validation accuracy: 0.8170
# Saving ...
#
# Epoch 116:
# Training loss: 0.6177, Training accuracy: 0.8252
# Validation loss: 0.5191, Validation accuracy: 0.8225
# Saving ...
#
# Epoch 117:
# Training loss: 0.6093, Training accuracy: 0.8283
# Validation loss: 0.5156, Validation accuracy: 0.8247
# Saving ...
#
# Epoch 118:
# Training loss: 0.6043, Training accuracy: 0.8307
# Validation loss: 0.5097, Validation accuracy: 0.8242
#
# Epoch 119:
# Training loss: 0.5971, Training accuracy: 0.8330
# Validation loss: 0.5029, Validation accuracy: 0.8277
# Saving ...
#
# Epoch 120:
# Training loss: 0.5890, Training accuracy: 0.8359
# Validation loss: 0.5024, Validation accuracy: 0.8284
# Saving ...
#
# Epoch 121:
# Training loss: 0.5855, Training accuracy: 0.8370
# Validation loss: 0.4927, Validation accuracy: 0.8294
# Saving ...
#
# Epoch 122:
# Training loss: 0.5781, Training accuracy: 0.8394
# Validation loss: 0.4977, Validation accuracy: 0.8308
# Saving ...
#
# Epoch 123:
# Training loss: 0.5741, Training accuracy: 0.8407
# Validation loss: 0.4831, Validation accuracy: 0.8351
# Saving ...
#
# Epoch 124:
# Training loss: 0.5694, Training accuracy: 0.8435
# Validation loss: 0.4877, Validation accuracy: 0.8337
#
# Epoch 125:
# Training loss: 0.5650, Training accuracy: 0.8449
# Validation loss: 0.4866, Validation accuracy: 0.8362
# Saving ...
#
# Epoch 126:
# Training loss: 0.5565, Training accuracy: 0.8465
# Validation loss: 0.4798, Validation accuracy: 0.8378
# Saving ...
#
# Epoch 127:
# Training loss: 0.5524, Training accuracy: 0.8496
# Validation loss: 0.4770, Validation accuracy: 0.8379
# Saving ...
#
# Epoch 128:
# Training loss: 0.5480, Training accuracy: 0.8501
# Validation loss: 0.4787, Validation accuracy: 0.8401
# Saving ...
#
# Epoch 129:
# Training loss: 0.5446, Training accuracy: 0.8517
# Validation loss: 0.4749, Validation accuracy: 0.8413
# Saving ...
#
# Epoch 130:
# Training loss: 0.5403, Training accuracy: 0.8523
# Validation loss: 0.4661, Validation accuracy: 0.8413
#
# Epoch 131:
# Training loss: 0.5371, Training accuracy: 0.8538
# Validation loss: 0.4734, Validation accuracy: 0.8405
#
# Epoch 132:
# Training loss: 0.5328, Training accuracy: 0.8550
# Validation loss: 0.4675, Validation accuracy: 0.8435
# Saving ...
#
# Epoch 133:
# Training loss: 0.5298, Training accuracy: 0.8581
# Validation loss: 0.4640, Validation accuracy: 0.8463
# Saving ...
#
# Epoch 134:
# Training loss: 0.5269, Training accuracy: 0.8574
# Validation loss: 0.4562, Validation accuracy: 0.8471
# Saving ...
#
# Epoch 135:
# Training loss: 0.5222, Training accuracy: 0.8595
# Validation loss: 0.4582, Validation accuracy: 0.8439
#
# Epoch 136:
# Training loss: 0.5181, Training accuracy: 0.8600
# Validation loss: 0.4582, Validation accuracy: 0.8463
#
# Epoch 137:
# Training loss: 0.5149, Training accuracy: 0.8619
# Validation loss: 0.4520, Validation accuracy: 0.8473
# Saving ...
#
# Epoch 138:
# Training loss: 0.5120, Training accuracy: 0.8633
# Validation loss: 0.4483, Validation accuracy: 0.8476
# Saving ...
#
# Epoch 139:
# Training loss: 0.5097, Training accuracy: 0.8637
# Validation loss: 0.4562, Validation accuracy: 0.8463
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.8476 with loss: 0.4483

# %% [markdown]
# ## 4.

# %%
import matplotlib.pyplot as plt
plt.plot(range(140),train_accs,label='train_accuracy')
plt.plot(range(140),val_accs,label='validation_accuracy')
plt.xlabel('episode')
plt.ylabel('accuracy')
plt.title('Accuracy vs Episode (rotation)-LAMBDA = 0.75')
plt.legend()
plt.show()

# %%
plt.plot(range(140),train_losses,label='train_loss')
plt.plot(range(140),val_losses,label='validation_loss')
plt.xlabel('episode')
plt.ylabel('loss')
plt.title('Loss vs Episode (rotation)-LAMBDA = 0.75')
plt.legend()
plt.show()
