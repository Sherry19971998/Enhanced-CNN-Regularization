# %% [markdown]
# # Improved Regularization of Convolutional Neural Networks (Step-5all)

# %% [markdown]
# ## 1. Resnet-20

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

# %%
def _weights_init(m):
    """
        Initialization of CNN weights
    """
    classname = m.__class__.__name__
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight)

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet20_rot(nn.Module):
    def __init__(self):
        super(ResNet20_rot, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)

        self.layer1 = self.blocks(16, 16, 3, stride=1)
        self.layer2 = self.blocks(16, 32, 3, stride=2)
        self.layer3 = self.blocks(32, 64, 3, stride=2)
        self.fc = nn.Linear(64, 10)
        self.fc_rotation = nn.Linear(64, 4) #rotation
        self.apply(_weights_init)

    def blocks(self, in_channels, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for i in strides:
            layers.append(ResidualBlock(in_channels, out_channels, i))
            in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1)
        out_classification = self.fc(out)
        out_rotation = self.fc_rotation(out) #rotation
        return out_classification, out_rotation

# %% [markdown]
# ## 2. Data Processing

# %%
class Cutout(object):
    """Randomly mask out one or more patches from an image.

    Args:
        n_holes (int): Number of patches to cut out of each image.
        length (int): The length (in pixels) of each square patch.
    """
    def __init__(self, n_holes, length):
        self.n_holes = n_holes
        self.length = length

    def __call__(self, img):
        """
        Args:
            img (Tensor): Tensor image of size (C, H, W).
        Returns:
            Tensor: Image with n_holes of dimension length x length cut out of it.
        """
        h = img.size(1)
        w = img.size(2)

        mask = np.ones((h, w), np.float32)

        for n in range(self.n_holes):
            y = np.random.randint(h)
            x = np.random.randint(w)

            y1 = np.clip(y - self.length // 2, 0, h)
            y2 = np.clip(y + self.length // 2, 0, h)
            x1 = np.clip(x - self.length // 2, 0, w)
            x2 = np.clip(x + self.length // 2, 0, w)

            mask[y1: y2, x1: x2] = 0.

        mask = torch.from_numpy(mask)
        mask = mask.expand_as(img)
        img = img * mask

        return img

# %%
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import Dataset, DataLoader

class CIFAR10WithRotation(Dataset):
    def __init__(self, root, train, transform):
        self.dataset = torchvision.datasets.CIFAR10(root=root, train=train, download=True, transform=transform)
        self.rotations = [0, 90, 180, 270]

    def __len__(self):
        return len(self.dataset) * len(self.rotations)

    def __getitem__(self, idx):
        image, label = self.dataset[idx % len(self.dataset)]
        rotation_idx = idx // len(self.dataset)
        rotation_angle = self.rotations[rotation_idx]
        rotated_image = transforms.functional.rotate(image, rotation_angle)
        return rotated_image, label, rotation_idx

normalize = transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],
                                     std=[0.2023, 0.1994, 0.2010])


train_loader = DataLoader(
        CIFAR10WithRotation(root='./data', train=True, transform=transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.RandomCrop(32, 4),
            transforms.ToTensor(),
            normalize,
            Cutout(n_holes=1, length= 20)
            # add cutout if needed, give n_holes, length parameters according to the essay
            # n_holes = 1, length = 16 by defalt
        ])),
        batch_size=128, shuffle=True,
        num_workers=4, pin_memory=True)

val_loader = DataLoader(
        datasets.CIFAR10(root='./data', train=False, transform=transforms.Compose([
            transforms.ToTensor(),
            normalize,
        ]), download=True),
        batch_size=128, shuffle=False,
        num_workers=4, pin_memory=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## 3. Model Training

# %%
def mixup_data(x, y,z, alpha, device):
    '''Returns mixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    index = torch.randperm(batch_size).to(device)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    z_a, z_b = z, z[index]
    return mixed_x, y_a, y_b,z_a, z_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
import torch.optim as optim

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = ResNet20_rot().to(device)

INITIAL_LR = 0.1
MOMENTUM = 0.9
REG = 1e-4
alpha = 0.2#mixup

criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)

# %%
import os
EPOCHS = 200
DECAY_EPOCHS = [60,120,160]#decay epoch change according to essay
DECAY = 0.2
LAMBDA = 0.75 #rotation
CHECKPOINT_FOLDER = "./saved_model"

best_val_acc = 0
best_val_acc_loss = 0
train_accs=[]
train_losses=[]
val_accs=[]
val_losses=[]
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
    if i in DECAY_EPOCHS:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)

    model.train()
    print("Epoch %d:" %i)
    total_examples = 0
    correct_examples = 0
    train_loss = 0

    for batch_idx, (inputs, targets, rotations) in enumerate(train_loader):
        inputs, targets, rotations = inputs.to(device), targets.to(device), rotations.to(device) #rotation
        inputs, targets_a, targets_b,rotations_a,rotations_b, lam = mixup_data(inputs, targets, rotations,alpha, device)#mixup rotation

        outputs, rotation_outputs = model(inputs)
        #loss = criterion(outputs, targets) + LAMBDA * criterion(rotation_outputs, rotations) #rotation
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam)+ LAMBDA * mixup_criterion(criterion, rotation_outputs, rotations_a, rotations_b, lam)#mixup rotation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total_examples += targets.size(0)
        #correct_examples += predicted.eq(targets).sum().item()
        correct_examples += (lam * predicted.eq(targets_a.data).cpu().sum().float()+ (1 - lam) * predicted.eq(targets_b.data).cpu().sum().float())#mixup




    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
    train_accs.append(avg_acc)
    train_losses.append(avg_loss)


    model.eval()
    total_examples = 0
    correct_examples = 0

    val_loss = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs, _ = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item()
            _, predicted = outputs.max(1)
            total_examples += targets.size(0)
            correct_examples += predicted.eq(targets).sum().item()

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    val_accs.append(avg_acc)
    val_losses.append(avg_loss)

    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        best_val_acc_loss = avg_loss
        if not os.path.exists(CHECKPOINT_FOLDER):
            os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': model.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'combine.pth'))

    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f} with loss: {best_val_acc_loss:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 2.5690, Training accuracy: 0.3878
# Validation loss: 1.3215, Validation accuracy: 0.5183
# Saving ...
#
# Epoch 1:
# Training loss: 2.2661, Training accuracy: 0.4770
# Validation loss: 1.1576, Validation accuracy: 0.5812
# Saving ...
#
# Epoch 2:
# Training loss: 2.1018, Training accuracy: 0.5179
# Validation loss: 1.2056, Validation accuracy: 0.5889
# Saving ...
#
# Epoch 3:
# Training loss: 1.9972, Training accuracy: 0.5485
# Validation loss: 0.9115, Validation accuracy: 0.6786
# Saving ...
#
# Epoch 4:
# Training loss: 1.9242, Training accuracy: 0.5683
# Validation loss: 1.5196, Validation accuracy: 0.5071
#
# Epoch 5:
# Training loss: 1.8714, Training accuracy: 0.5817
# Validation loss: 0.8622, Validation accuracy: 0.7031
# Saving ...
#
# Epoch 6:
# Training loss: 1.8556, Training accuracy: 0.5861
# Validation loss: 0.8402, Validation accuracy: 0.7077
# Saving ...
#
# Epoch 7:
# Training loss: 1.8085, Training accuracy: 0.6004
# Validation loss: 0.8607, Validation accuracy: 0.7001
#
# Epoch 8:
# Training loss: 1.7978, Training accuracy: 0.6040
# Validation loss: 0.8809, Validation accuracy: 0.6962
#
# Epoch 9:
# Training loss: 1.7775, Training accuracy: 0.6078
# Validation loss: 0.9608, Validation accuracy: 0.6703
#
# Epoch 10:
# Training loss: 1.7567, Training accuracy: 0.6147
# Validation loss: 0.7798, Validation accuracy: 0.7286
# Saving ...
#
# Epoch 11:
# Training loss: 1.7584, Training accuracy: 0.6134
# Validation loss: 0.9156, Validation accuracy: 0.6866
#
# Epoch 12:
# Training loss: 1.7460, Training accuracy: 0.6165
# Validation loss: 1.1501, Validation accuracy: 0.5900
#
# Epoch 13:
# Training loss: 1.7108, Training accuracy: 0.6241
# Validation loss: 0.8245, Validation accuracy: 0.7100
#
# Epoch 14:
# Training loss: 1.7004, Training accuracy: 0.6264
# Validation loss: 0.7188, Validation accuracy: 0.7460
#
# Epoch 62:
# Training loss: 1.3972, Training accuracy: 0.7045
# Validation loss: 0.4815, Validation accuracy: 0.8411
# Saving ...
#
# Epoch 63:
# Training loss: 1.4099, Training accuracy: 0.7032
# Validation loss: 0.4624, Validation accuracy: 0.8481
# Saving ...
#
# Epoch 64:
# Training loss: 1.3969, Training accuracy: 0.7048
# Validation loss: 0.4242, Validation accuracy: 0.8557
# Saving ...
#
# Epoch 65:
# Training loss: 1.4046, Training accuracy: 0.7055
# Validation loss: 0.4905, Validation accuracy: 0.8339
#
# Epoch 66:
# Training loss: 1.3867, Training accuracy: 0.7077
# Validation loss: 0.4731, Validation accuracy: 0.8454
#
# Epoch 67:
# Training loss: 1.3767, Training accuracy: 0.7101
# Validation loss: 0.4897, Validation accuracy: 0.8370
#
# Epoch 68:
# Training loss: 1.3771, Training accuracy: 0.7103
# Validation loss: 0.4747, Validation accuracy: 0.8350
#
# Epoch 69:
# Training loss: 1.3889, Training accuracy: 0.7072
# Validation loss: 0.4708, Validation accuracy: 0.8428
#
# Epoch 70:
# Training loss: 1.3870, Training accuracy: 0.7057
# Validation loss: 0.4599, Validation accuracy: 0.8442
#
# Epoch 71:
# Training loss: 1.3869, Training accuracy: 0.7078
# Validation loss: 0.4619, Validation accuracy: 0.8506
#
# Epoch 72:
# Training loss: 1.3899, Training accuracy: 0.7074
# Validation loss: 0.4764, Validation accuracy: 0.8402
#
# Epoch 73:
# Training loss: 1.3847, Training accuracy: 0.7067
# Validation loss: 0.4750, Validation accuracy: 0.8425
#
# Epoch 74:
# Training loss: 1.3886, Training accuracy: 0.7053
# Validation loss: 0.4947, Validation accuracy: 0.8387
#
# Epoch 75:
# Training loss: 1.3861, Training accuracy: 0.7096
# Validation loss: 0.4816, Validation accuracy: 0.8393
#
# Epoch 76:
# Training loss: 1.4039, Training accuracy: 0.7030
# Validation loss: 0.4903, Validation accuracy: 0.8310
#
# Epoch 77:
# Training loss: 1.4163, Training accuracy: 0.7020
# Validation loss: 0.4907, Validation accuracy: 0.8347
#
# Epoch 78:
# Training loss: 1.3967, Training accuracy: 0.7057
# Validation loss: 0.5015, Validation accuracy: 0.8305
#
# Epoch 79:
# Training loss: 1.3955, Training accuracy: 0.7050
# Validation loss: 0.4851, Validation accuracy: 0.8439
#
# Epoch 80:
# Training loss: 1.4023, Training accuracy: 0.7051
# Validation loss: 0.4593, Validation accuracy: 0.8472
#
# Epoch 81:
# Training loss: 1.3833, Training accuracy: 0.7078
# Validation loss: 0.4681, Validation accuracy: 0.8419
#
# Epoch 82:
# Training loss: 1.3844, Training accuracy: 0.7086
# Validation loss: 0.5269, Validation accuracy: 0.8346
#
# Epoch 83:
# Training loss: 1.4026, Training accuracy: 0.7046
# Validation loss: 0.5309, Validation accuracy: 0.8310
#
# Epoch 84:
# Training loss: 1.3855, Training accuracy: 0.7082
# Validation loss: 0.4504, Validation accuracy: 0.8476
#
# Epoch 85:
# Training loss: 1.4164, Training accuracy: 0.7015
# Validation loss: 0.5573, Validation accuracy: 0.8091
#
# Epoch 110:
# Training loss: 1.3707, Training accuracy: 0.7113
# Validation loss: 0.5071, Validation accuracy: 0.8301
#
# Epoch 111:
# Training loss: 1.3747, Training accuracy: 0.7114
# Validation loss: 0.4629, Validation accuracy: 0.8432
#
# Epoch 112:
# Training loss: 1.3554, Training accuracy: 0.7144
# Validation loss: 0.5172, Validation accuracy: 0.8289
#
# Epoch 113:
# Training loss: 1.4090, Training accuracy: 0.7041
# Validation loss: 0.4929, Validation accuracy: 0.8477
#
# Epoch 114:
# Training loss: 1.4086, Training accuracy: 0.7032
# Validation loss: 0.4377, Validation accuracy: 0.8517
#
# Epoch 115:
# Training loss: 1.3733, Training accuracy: 0.7108
# Validation loss: 0.4780, Validation accuracy: 0.8349
#
# Epoch 116:
# Training loss: 1.3595, Training accuracy: 0.7132
# Validation loss: 0.4234, Validation accuracy: 0.8562
# Saving ...
#
# Epoch 117:
# Training loss: 1.3876, Training accuracy: 0.7086
# Validation loss: 0.4897, Validation accuracy: 0.8407
#
# Epoch 118:
# Training loss: 1.3777, Training accuracy: 0.7090
# Validation loss: 0.4978, Validation accuracy: 0.8309
#
# Epoch 119:
# Training loss: 1.4035, Training accuracy: 0.7044
# Validation loss: 0.4531, Validation accuracy: 0.8475
#
# Current learning rate has decayed to 0.004000
# Epoch 120:
# Training loss: 1.3470, Training accuracy: 0.7201
# Validation loss: 0.4193, Validation accuracy: 0.8696
# Saving ...
#
# Epoch 121:
# Training loss: 1.2856, Training accuracy: 0.7346
# Validation loss: 0.3696, Validation accuracy: 0.8760
# Saving ...
#
# Epoch 122:
# Training loss: 1.2860, Training accuracy: 0.7347
# Validation loss: 0.4151, Validation accuracy: 0.8752
#
# Epoch 123:
# Training loss: 1.3024, Training accuracy: 0.7309
# Validation loss: 0.3998, Validation accuracy: 0.8790
# Saving ...
#
# Epoch 124:
# Training loss: 1.2559, Training accuracy: 0.7409
# Validation loss: 0.3729, Validation accuracy: 0.8779
#
# Epoch 125:
# Training loss: 1.2860, Training accuracy: 0.7340
# Validation loss: 0.3790, Validation accuracy: 0.8775
#
# Epoch 126:
# Training loss: 1.2630, Training accuracy: 0.7392
# Validation loss: 0.3880, Validation accuracy: 0.8761
#
# Epoch 127:
# Training loss: 1.2763, Training accuracy: 0.7359
# Validation loss: 0.3707, Validation accuracy: 0.8795
# Saving ...
#
# Epoch 128:
# Training loss: 1.2538, Training accuracy: 0.7411
# Validation loss: 0.3691, Validation accuracy: 0.8775
#
# Epoch 129:
# Training loss: 1.2647, Training accuracy: 0.7390
# Validation loss: 0.3515, Validation accuracy: 0.8792
#
# Epoch 130:
# Training loss: 1.2711, Training accuracy: 0.7386
# Validation loss: 0.3644, Validation accuracy: 0.8781
#
# Epoch 131:
# Training loss: 1.2848, Training accuracy: 0.7359
# Validation loss: 0.3902, Validation accuracy: 0.8784
#
# Epoch 132:
# Training loss: 1.2802, Training accuracy: 0.7362
# Validation loss: 0.3803, Validation accuracy: 0.8824
# Saving ...
#
# Epoch 133:
# Training loss: 1.2751, Training accuracy: 0.7382
# Validation loss: 0.3916, Validation accuracy: 0.8799
#
# Epoch 134:
# Training loss: 1.2521, Training accuracy: 0.7415
# Validation loss: 0.3805, Validation accuracy: 0.8813
#
# Epoch 135:
# Training loss: 1.2381, Training accuracy: 0.7441
# Validation loss: 0.3826, Validation accuracy: 0.8791
#
# Epoch 136:
# Training loss: 1.3349, Training accuracy: 0.7244
# Validation loss: 0.4172, Validation accuracy: 0.8758
#
# Epoch 137:
# Training loss: 1.2807, Training accuracy: 0.7362
# Validation loss: 0.3799, Validation accuracy: 0.8813
#
# Epoch 138:
# Training loss: 1.2445, Training accuracy: 0.7430
# Validation loss: 0.3749, Validation accuracy: 0.8794
#
# Epoch 139:
# Training loss: 1.2516, Training accuracy: 0.7418
# Validation loss: 0.3905, Validation accuracy: 0.8781
#
# Epoch 140:
# Training loss: 1.2628, Training accuracy: 0.7392
# Validation loss: 0.3604, Validation accuracy: 0.8802
#
# Epoch 141:
# Training loss: 1.2743, Training accuracy: 0.7372
# Validation loss: 0.4068, Validation accuracy: 0.8805
#
# Epoch 142:
# Training loss: 1.2640, Training accuracy: 0.7387
# Validation loss: 0.3879, Validation accuracy: 0.8762
#
# Epoch 143:
# Training loss: 1.2547, Training accuracy: 0.7431
# Validation loss: 0.3779, Validation accuracy: 0.8858
# Saving ...
#
# Epoch 144:
# Training loss: 1.2503, Training accuracy: 0.7426
# Validation loss: 0.3860, Validation accuracy: 0.8769
#
# Epoch 145:
# Training loss: 1.2861, Training accuracy: 0.7374
# Validation loss: 0.3778, Validation accuracy: 0.8772
#
# Epoch 146:
# Training loss: 1.2766, Training accuracy: 0.7362
# Validation loss: 0.3736, Validation accuracy: 0.8791
#
# Epoch 147:
# Training loss: 1.2511, Training accuracy: 0.7429
# Validation loss: 0.3584, Validation accuracy: 0.8833
#
# Epoch 148:
# Training loss: 1.2472, Training accuracy: 0.7422
# Validation loss: 0.3803, Validation accuracy: 0.8811
#
# Epoch 149:
# Training loss: 1.2731, Training accuracy: 0.7379
# Validation loss: 0.3694, Validation accuracy: 0.8770
#
# Epoch 150:
# Training loss: 1.2857, Training accuracy: 0.7358
# Validation loss: 0.4309, Validation accuracy: 0.8748
#
# Epoch 151:
# Training loss: 1.2462, Training accuracy: 0.7415
# Validation loss: 0.4042, Validation accuracy: 0.8716
#
# Epoch 152:
# Training loss: 1.2334, Training accuracy: 0.7466
# Validation loss: 0.4119, Validation accuracy: 0.8734
#
# Epoch 153:
# Training loss: 1.2714, Training accuracy: 0.7382
# Validation loss: 0.3851, Validation accuracy: 0.8742
#
# Epoch 154:
# Training loss: 1.2600, Training accuracy: 0.7417
# Validation loss: 0.3545, Validation accuracy: 0.8809
#
# Epoch 155:
# Training loss: 1.2813, Training accuracy: 0.7345
# Validation loss: 0.3897, Validation accuracy: 0.8722
#
# Epoch 156:
# Training loss: 1.2689, Training accuracy: 0.7389
# Validation loss: 0.3837, Validation accuracy: 0.8769
#
# Epoch 157:
# Training loss: 1.2522, Training accuracy: 0.7425
# Validation loss: 0.3983, Validation accuracy: 0.8763
#
# Epoch 158:
# Training loss: 1.2828, Training accuracy: 0.7354
# Validation loss: 0.3722, Validation accuracy: 0.8830
#
# Epoch 159:
# Training loss: 1.2818, Training accuracy: 0.7353
# Validation loss: 0.3894, Validation accuracy: 0.8785
#
# Current learning rate has decayed to 0.000800
# Epoch 160:
# Training loss: 1.2529, Training accuracy: 0.7428
# Validation loss: 0.3374, Validation accuracy: 0.8875
# Saving ...
#
# Epoch 161:
# Training loss: 1.2091, Training accuracy: 0.7536
# Validation loss: 0.3598, Validation accuracy: 0.8862
#
# Epoch 162:
# Training loss: 1.2198, Training accuracy: 0.7502
# Validation loss: 0.3486, Validation accuracy: 0.8894
# Saving ...
#
# Epoch 163:
# Training loss: 1.2283, Training accuracy: 0.7481
# Validation loss: 0.3736, Validation accuracy: 0.8866
#
# Epoch 164:
# Training loss: 1.2225, Training accuracy: 0.7501
# Validation loss: 0.3554, Validation accuracy: 0.8867
#
# Epoch 165:
# Training loss: 1.2159, Training accuracy: 0.7530
# Validation loss: 0.3423, Validation accuracy: 0.8891
#
# Epoch 166:
# Training loss: 1.2233, Training accuracy: 0.7497
# Validation loss: 0.3520, Validation accuracy: 0.8876
#
# Epoch 167:
# Training loss: 1.2056, Training accuracy: 0.7528
# Validation loss: 0.3466, Validation accuracy: 0.8874
#
# Epoch 168:
# Training loss: 1.2132, Training accuracy: 0.7524
# Validation loss: 0.3456, Validation accuracy: 0.8896
# Saving ...
#
# Epoch 169:
# Training loss: 1.2012, Training accuracy: 0.7566
# Validation loss: 0.3699, Validation accuracy: 0.8883
#
# Epoch 170:
# Training loss: 1.2276, Training accuracy: 0.7484
# Validation loss: 0.3755, Validation accuracy: 0.8843
#
# Epoch 171:
# Training loss: 1.1904, Training accuracy: 0.7565
# Validation loss: 0.3553, Validation accuracy: 0.8887
#
# Epoch 172:
# Training loss: 1.2286, Training accuracy: 0.7498
# Validation loss: 0.3533, Validation accuracy: 0.8868
#
# Epoch 173:
# Training loss: 1.2172, Training accuracy: 0.7515
# Validation loss: 0.3715, Validation accuracy: 0.8874
#
# Epoch 174:
# Training loss: 1.2080, Training accuracy: 0.7553
# Validation loss: 0.3827, Validation accuracy: 0.8848
#
# Epoch 175:
# Training loss: 1.1967, Training accuracy: 0.7559
# Validation loss: 0.3643, Validation accuracy: 0.8887
#
# Epoch 176:
# Training loss: 1.2247, Training accuracy: 0.7504
# Validation loss: 0.3712, Validation accuracy: 0.8849
#
# Epoch 177:
# Training loss: 1.2240, Training accuracy: 0.7509
# Validation loss: 0.3327, Validation accuracy: 0.8874
#
# Epoch 178:
# Training loss: 1.2496, Training accuracy: 0.7445
# Validation loss: 0.3491, Validation accuracy: 0.8878
#
# Epoch 179:
# Training loss: 1.2238, Training accuracy: 0.7501
# Validation loss: 0.3406, Validation accuracy: 0.8884
#
# Epoch 180:
# Training loss: 1.2342, Training accuracy: 0.7485
# Validation loss: 0.3721, Validation accuracy: 0.8865
#
# Epoch 181:
# Training loss: 1.2148, Training accuracy: 0.7528
# Validation loss: 0.3498, Validation accuracy: 0.8885
#
# Epoch 182:
# Training loss: 1.1936, Training accuracy: 0.7576
# Validation loss: 0.3358, Validation accuracy: 0.8917
# Saving ...
#
# Epoch 183:
# Training loss: 1.2179, Training accuracy: 0.7521
# Validation loss: 0.3764, Validation accuracy: 0.8865
#
# Epoch 184:
# Training loss: 1.1966, Training accuracy: 0.7573
# Validation loss: 0.3261, Validation accuracy: 0.8918
# Saving ...
#
# Epoch 185:
# Training loss: 1.2404, Training accuracy: 0.7465
# Validation loss: 0.3286, Validation accuracy: 0.8892
#
# Epoch 186:
# Training loss: 1.2113, Training accuracy: 0.7539
# Validation loss: 0.3394, Validation accuracy: 0.8890
#
# Epoch 187:
# Training loss: 1.2478, Training accuracy: 0.7450
# Validation loss: 0.3724, Validation accuracy: 0.8859
#
# Epoch 188:
# Training loss: 1.2084, Training accuracy: 0.7536
# Validation loss: 0.3410, Validation accuracy: 0.8865
#
# Epoch 189:
# Training loss: 1.2097, Training accuracy: 0.7531
# Validation loss: 0.3680, Validation accuracy: 0.8886
#
# Epoch 190:
# Training loss: 1.2075, Training accuracy: 0.7542
# Validation loss: 0.3678, Validation accuracy: 0.8865
#
# Epoch 191:
# Training loss: 1.1860, Training accuracy: 0.7586
# Validation loss: 0.3545, Validation accuracy: 0.8882
#
# Epoch 192:
# Training loss: 1.2276, Training accuracy: 0.7485
# Validation loss: 0.3481, Validation accuracy: 0.8875
#
# Epoch 193:
# Training loss: 1.2218, Training accuracy: 0.7517
# Validation loss: 0.3541, Validation accuracy: 0.8882
#
# Epoch 194:
# Training loss: 1.2076, Training accuracy: 0.7530
# Validation loss: 0.3452, Validation accuracy: 0.8885
#
# Epoch 195:
# Training loss: 1.2194, Training accuracy: 0.7521
# Validation loss: 0.3578, Validation accuracy: 0.8876
#
# Epoch 196:
# Training loss: 1.1952, Training accuracy: 0.7576
# Validation loss: 0.3336, Validation accuracy: 0.8896
#
# Epoch 197:
# Training loss: 1.2137, Training accuracy: 0.7542
# Validation loss: 0.3719, Validation accuracy: 0.8848
#
# Epoch 198:
# Training loss: 1.2168, Training accuracy: 0.7519
# Validation loss: 0.3217, Validation accuracy: 0.8909
#
# Epoch 199:
# Training loss: 1.2153, Training accuracy: 0.7523
# Validation loss: 0.3458, Validation accuracy: 0.8878
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.8918 with loss: 0.3261

# %% [markdown]
# ## 4.

# %%
import matplotlib.pyplot as plt
plt.plot(range(200),train_accs,label='train_accuracy')
plt.plot(range(200),val_accs,label='validation_accuracy')
plt.xlabel('episode')
plt.ylabel('accuracy')
plt.title('Accuracy vs Episode (combine)')
plt.legend()
plt.show()

# %%
plt.plot(range(200),train_losses,label='train_loss')
plt.plot(range(200),val_losses,label='validation_loss')
plt.xlabel('episode')
plt.ylabel('loss')
plt.title('Loss vs Episode (combine)')
plt.legend()
plt.show()
