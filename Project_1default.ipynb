# %% [markdown]
# # Project 5: Improved Regularization of Convolutional Neural Networks

# %% [markdown]
# ## 1. Resnet-20

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

# %%
def _weights_init(m):
    """
        Initialization of CNN weights
    """
    classname = m.__class__.__name__
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight)

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet20(nn.Module):
    def __init__(self):
        super(ResNet20, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)

        self.layer1 = self.blocks(16, 16, 3, stride=1)
        self.layer2 = self.blocks(16, 32, 3, stride=2)
        self.layer3 = self.blocks(32, 64, 3, stride=2)
        self.fc = nn.Linear(64, 10)
        self.apply(_weights_init)

    def blocks(self, in_channels, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for i in strides:
            layers.append(ResidualBlock(in_channels, out_channels, i))
            in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

# %% [markdown]
# ## 2. Data Processing

# %%
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader


normalize = transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],
                                     std=[0.2023, 0.1994, 0.2010])


train_loader = DataLoader(
        datasets.CIFAR10(root='./data', train=True, transform=transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.RandomCrop(32, 4),
            transforms.ToTensor(),
            normalize,
        ]), download=True),
        batch_size=128, shuffle=True,
        num_workers=4, pin_memory=True)

val_loader = DataLoader(
        datasets.CIFAR10(root='./data', train=False, transform=transforms.Compose([
            transforms.ToTensor(),
            normalize,
        ])),
        batch_size=128, shuffle=False,
        num_workers=4, pin_memory=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:13<00:00, 12305197.58it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ## 3. Model Training

# %%
import torch.optim as optim

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = ResNet20().to(device)

INITIAL_LR = 0.1
MOMENTUM = 0.9
REG = 1e-4

criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)

# %%
import os
EPOCHS = 200
DECAY_EPOCHS = [60,120,160]
#DECAY_EPOCHS = [100,150]
DECAY = 0.1

CHECKPOINT_FOLDER = "./saved_model"

best_val_acc = 0
best_val_acc_loss = 0
train_accs=[]
train_losses=[]
val_accs=[]
val_losses=[]
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
    if i in DECAY_EPOCHS:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)

    model.train()
    print("Epoch %d:" %i)
    total_examples = 0
    correct_examples = 0
    train_loss = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = model(inputs)
        loss = criterion(outputs, targets)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total_examples += targets.size(0)
        correct_examples += predicted.eq(targets).sum().item()


    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
    train_accs.append(avg_acc)
    train_losses.append(avg_loss)



    model.eval()
    total_examples = 0
    correct_examples = 0

    val_loss = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item()
            _, predicted = outputs.max(1)
            total_examples += targets.size(0)
            correct_examples += predicted.eq(targets).sum().item()

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    val_accs.append(avg_acc)
    val_losses.append(avg_loss)

    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        best_val_acc_loss = avg_loss
        if not os.path.exists(CHECKPOINT_FOLDER):
            os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': model.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'resnet.pth'))

    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f} with loss: {best_val_acc_loss:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.5722, Training accuracy: 0.4175
# Validation loss: 1.2527, Validation accuracy: 0.5517
# Saving ...
#
# Epoch 1:
# Training loss: 1.0627, Training accuracy: 0.6187
# Validation loss: 1.0008, Validation accuracy: 0.6539
# Saving ...
#
# Epoch 2:
# Training loss: 0.8429, Training accuracy: 0.7020
# Validation loss: 0.7838, Validation accuracy: 0.7284
# Saving ...
#
# Epoch 3:
# Training loss: 0.7164, Training accuracy: 0.7493
# Validation loss: 1.1056, Validation accuracy: 0.6591
#
# Epoch 4:
# Training loss: 0.6470, Training accuracy: 0.7739
# Validation loss: 0.7313, Validation accuracy: 0.7573
# Saving ...
#
# Epoch 5:
# Training loss: 0.5927, Training accuracy: 0.7961
# Validation loss: 0.6149, Validation accuracy: 0.7880
# Saving ...
#
# Epoch 6:
# Training loss: 0.5517, Training accuracy: 0.8096
# Validation loss: 0.7597, Validation accuracy: 0.7564
#
# Epoch 7:
# Training loss: 0.5226, Training accuracy: 0.8200
# Validation loss: 0.6020, Validation accuracy: 0.7981
# Saving ...
#
# Epoch 8:
# Training loss: 0.4962, Training accuracy: 0.8284
# Validation loss: 0.5883, Validation accuracy: 0.8062
# Saving ...
#
# Epoch 9:
# Training loss: 0.4775, Training accuracy: 0.8342
# Validation loss: 0.7244, Validation accuracy: 0.7674
#
# Epoch 10:
# Training loss: 0.4594, Training accuracy: 0.8399
# Validation loss: 0.5810, Validation accuracy: 0.8048
#
# Epoch 11:
# Training loss: 0.4389, Training accuracy: 0.8481
# Validation loss: 0.6227, Validation accuracy: 0.7968
#
# Epoch 12:
# Training loss: 0.4233, Training accuracy: 0.8537
# Validation loss: 0.6082, Validation accuracy: 0.7952
#
# Epoch 13:
# Training loss: 0.4168, Training accuracy: 0.8557
# Validation loss: 0.5604, Validation accuracy: 0.8139
# Saving ...
#
# Epoch 14:
# Training loss: 0.3995, Training accuracy: 0.8629
# Validation loss: 0.6020, Validation accuracy: 0.8055
#
# Epoch 15:
# Training loss: 0.3938, Training accuracy: 0.8633
# Validation loss: 0.4825, Validation accuracy: 0.8392
# Saving ...
#
# Epoch 16:
#
# Epoch 157:
# Training loss: 0.0191, Training accuracy: 0.9952
# Validation loss: 0.3800, Validation accuracy: 0.9120
#
# Epoch 158:
# Training loss: 0.0188, Training accuracy: 0.9955
# Validation loss: 0.3831, Validation accuracy: 0.9117
#
# Epoch 159:
# Training loss: 0.0207, Training accuracy: 0.9940
# Validation loss: 0.3800, Validation accuracy: 0.9116
#
# Current learning rate has decayed to 0.000100
# Epoch 160:
# Training loss: 0.0207, Training accuracy: 0.9942
# Validation loss: 0.3831, Validation accuracy: 0.9113
#
# Epoch 161:
# Training loss: 0.0202, Training accuracy: 0.9946
# Validation loss: 0.3795, Validation accuracy: 0.9130
#
# Epoch 162:
# Training loss: 0.0199, Training accuracy: 0.9946
# Validation loss: 0.3793, Validation accuracy: 0.9107
#
# Epoch 163:
# Training loss: 0.0199, Training accuracy: 0.9947
# Validation loss: 0.3790, Validation accuracy: 0.9123
#
# Epoch 164:
# Training loss: 0.0186, Training accuracy: 0.9953
# Validation loss: 0.3790, Validation accuracy: 0.9121
#
# Epoch 165:
# Training loss: 0.0197, Training accuracy: 0.9946
# Validation loss: 0.3823, Validation accuracy: 0.9108
#
# Epoch 166:
# Training loss: 0.0198, Training accuracy: 0.9948
# Validation loss: 0.3779, Validation accuracy: 0.9129
#
# Epoch 167:
# Training loss: 0.0185, Training accuracy: 0.9951
# Validation loss: 0.3774, Validation accuracy: 0.9124
#
# Epoch 168:
# Training loss: 0.0204, Training accuracy: 0.9948
# Validation loss: 0.3770, Validation accuracy: 0.9128
#
# Epoch 169:
# Training loss: 0.0180, Training accuracy: 0.9952
# Validation loss: 0.3798, Validation accuracy: 0.9112
#
# Epoch 170:
# Training loss: 0.0196, Training accuracy: 0.9947
# Validation loss: 0.3797, Validation accuracy: 0.9114
#
# Epoch 171:
# Training loss: 0.0195, Training accuracy: 0.9950
# Validation loss: 0.3780, Validation accuracy: 0.9120
#
# Epoch 172:
# Training loss: 0.0196, Training accuracy: 0.9947
# Validation loss: 0.3807, Validation accuracy: 0.9124
#
# Epoch 173:
# Training loss: 0.0194, Training accuracy: 0.9949
# Validation loss: 0.3825, Validation accuracy: 0.9113
#
# Epoch 174:
# Training loss: 0.0201, Training accuracy: 0.9946
# Validation loss: 0.3766, Validation accuracy: 0.9111
#
# Epoch 175:
# Training loss: 0.0202, Training accuracy: 0.9943
# Validation loss: 0.3826, Validation accuracy: 0.9118
#
# Epoch 176:
# Training loss: 0.0196, Training accuracy: 0.9950
# Validation loss: 0.3816, Validation accuracy: 0.9121
#
# Epoch 177:
# Training loss: 0.0184, Training accuracy: 0.9954
# Validation loss: 0.3779, Validation accuracy: 0.9117
#
# Epoch 178:
# Training loss: 0.0201, Training accuracy: 0.9942
# Validation loss: 0.3776, Validation accuracy: 0.9117
#
# Epoch 179:
# Training loss: 0.0184, Training accuracy: 0.9950
# Validation loss: 0.3762, Validation accuracy: 0.9118
#
# Epoch 180:
# Training loss: 0.0187, Training accuracy: 0.9949
# Validation loss: 0.3807, Validation accuracy: 0.9112
#
# Epoch 181:
# Training loss: 0.0201, Training accuracy: 0.9943
# Validation loss: 0.3800, Validation accuracy: 0.9113
#
# Epoch 182:
# Training loss: 0.0185, Training accuracy: 0.9952
# Validation loss: 0.3815, Validation accuracy: 0.9106
#
# Epoch 183:
# Training loss: 0.0196, Training accuracy: 0.9946
# Validation loss: 0.3803, Validation accuracy: 0.9105
#
# Epoch 184:
# Training loss: 0.0189, Training accuracy: 0.9952
# Validation loss: 0.3778, Validation accuracy: 0.9111
#
# Epoch 185:
# Training loss: 0.0185, Training accuracy: 0.9952
# Validation loss: 0.3811, Validation accuracy: 0.9118
#
# Epoch 186:
# Training loss: 0.0188, Training accuracy: 0.9952
# Validation loss: 0.3779, Validation accuracy: 0.9105
#
# Epoch 187:
# Training loss: 0.0188, Training accuracy: 0.9952
# Validation loss: 0.3832, Validation accuracy: 0.9109
#
# Epoch 188:
# Training loss: 0.0196, Training accuracy: 0.9947
# Validation loss: 0.3804, Validation accuracy: 0.9128
#
# Epoch 189:
# Training loss: 0.0194, Training accuracy: 0.9950
# Validation loss: 0.3799, Validation accuracy: 0.9126
#
# Epoch 190:
# Training loss: 0.0185, Training accuracy: 0.9954
# Validation loss: 0.3786, Validation accuracy: 0.9110
#
# Epoch 191:
# Training loss: 0.0187, Training accuracy: 0.9951
# Validation loss: 0.3770, Validation accuracy: 0.9122
#
# Epoch 192:
# Training loss: 0.0176, Training accuracy: 0.9956
# Validation loss: 0.3782, Validation accuracy: 0.9113
#
# Epoch 193:
# Training loss: 0.0188, Training accuracy: 0.9954
# Validation loss: 0.3808, Validation accuracy: 0.9109
#
# Epoch 194:
# Training loss: 0.0191, Training accuracy: 0.9950
# Validation loss: 0.3778, Validation accuracy: 0.9131
#
# Epoch 195:
# Training loss: 0.0185, Training accuracy: 0.9953
# Validation loss: 0.3792, Validation accuracy: 0.9119
#
# Epoch 196:
# Training loss: 0.0183, Training accuracy: 0.9951
# Validation loss: 0.3773, Validation accuracy: 0.9106
#
# Epoch 197:
# Training loss: 0.0183, Training accuracy: 0.9957
# Validation loss: 0.3772, Validation accuracy: 0.9108
#
# Epoch 198:
# Training loss: 0.0189, Training accuracy: 0.9954
# Validation loss: 0.3767, Validation accuracy: 0.9124
#
# Epoch 199:
# Training loss: 0.0190, Training accuracy: 0.9950
# Validation loss: 0.3814, Validation accuracy: 0.9099
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.9145 with loss: 0.3077

# %% [markdown]
# ## 4.

# %%
import matplotlib.pyplot as plt
plt.plot(range(200),train_accs,label='train_accuracy')
plt.plot(range(200),val_accs,label='validation_accuracy')
plt.xlabel('episode')
plt.ylabel('accuracy')
plt.title('Accuracy vs Episode (resnet)')
plt.legend()
plt.show()

# %%
plt.plot(range(200),train_losses,label='train_loss')
plt.plot(range(200),val_losses,label='validation_loss')
plt.xlabel('episode')
plt.ylabel('loss')
plt.title('Loss vs Episode (resnet)')
plt.legend()
plt.show()
