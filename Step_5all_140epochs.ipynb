# %% [markdown]
# # Improved Regularization of Convolutional Neural Networks (Step-5all-140epochs)

# %% [markdown]
# ## 1. Resnet-20

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

# %%
def _weights_init(m):
    """
        Initialization of CNN weights
    """
    classname = m.__class__.__name__
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight)

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet20_rot(nn.Module):
    def __init__(self):
        super(ResNet20_rot, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)

        self.layer1 = self.blocks(16, 16, 3, stride=1)
        self.layer2 = self.blocks(16, 32, 3, stride=2)
        self.layer3 = self.blocks(32, 64, 3, stride=2)
        self.fc = nn.Linear(64, 10)
        self.fc_rotation = nn.Linear(64, 4) #rotation
        self.apply(_weights_init)

    def blocks(self, in_channels, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for i in strides:
            layers.append(ResidualBlock(in_channels, out_channels, i))
            in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1)
        out_classification = self.fc(out)
        out_rotation = self.fc_rotation(out) #rotation
        return out_classification, out_rotation

# %% [markdown]
# ## 2. Data Processing

# %%
class Cutout(object):
    """Randomly mask out one or more patches from an image.

    Args:
        n_holes (int): Number of patches to cut out of each image.
        length (int): The length (in pixels) of each square patch.
    """
    def __init__(self, n_holes, length):
        self.n_holes = n_holes
        self.length = length

    def __call__(self, img):
        """
        Args:
            img (Tensor): Tensor image of size (C, H, W).
        Returns:
            Tensor: Image with n_holes of dimension length x length cut out of it.
        """
        h = img.size(1)
        w = img.size(2)

        mask = np.ones((h, w), np.float32)

        for n in range(self.n_holes):
            y = np.random.randint(h)
            x = np.random.randint(w)

            y1 = np.clip(y - self.length // 2, 0, h)
            y2 = np.clip(y + self.length // 2, 0, h)
            x1 = np.clip(x - self.length // 2, 0, w)
            x2 = np.clip(x + self.length // 2, 0, w)

            mask[y1: y2, x1: x2] = 0.

        mask = torch.from_numpy(mask)
        mask = mask.expand_as(img)
        img = img * mask

        return img

# %%
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import Dataset, DataLoader

class CIFAR10WithRotation(Dataset):
    def __init__(self, root, train, transform):
        self.dataset = torchvision.datasets.CIFAR10(root=root, train=train, download=True, transform=transform)
        self.rotations = [0, 90, 180, 270]

    def __len__(self):
        return len(self.dataset) * len(self.rotations)

    def __getitem__(self, idx):
        image, label = self.dataset[idx % len(self.dataset)]
        rotation_idx = idx // len(self.dataset)
        rotation_angle = self.rotations[rotation_idx]
        rotated_image = transforms.functional.rotate(image, rotation_angle)
        return rotated_image, label, rotation_idx

normalize = transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],
                                     std=[0.2023, 0.1994, 0.2010])


train_loader = DataLoader(
        CIFAR10WithRotation(root='./data', train=True, transform=transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.RandomCrop(32, 4),
            transforms.ToTensor(),
            normalize,
            Cutout(n_holes=1, length= 20)
            # add cutout if needed, give n_holes, length parameters according to the essay
            # n_holes = 1, length = 16 by defalt
        ])),
        batch_size=128, shuffle=True,
        num_workers=4, pin_memory=True)

val_loader = DataLoader(
        datasets.CIFAR10(root='./data', train=False, transform=transforms.Compose([
            transforms.ToTensor(),
            normalize,
        ]), download=True),
        batch_size=128, shuffle=False,
        num_workers=4, pin_memory=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:05<00:00, 28940446.21it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ## 3. Model Training

# %%
def mixup_data(x, y,z, alpha, device):
    '''Returns mixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    index = torch.randperm(batch_size).to(device)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    z_a, z_b = z, z[index]
    return mixed_x, y_a, y_b,z_a, z_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
import torch.optim as optim

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = ResNet20_rot().to(device)

INITIAL_LR = 0.1
MOMENTUM = 0.9
REG = 1e-4
alpha = 0.2#mixup

criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)

# %%
import os
EPOCHS = 140
DECAY_EPOCHS = [30,60,100]#decay epoch change according to essay
DECAY = 0.2
LAMBDA = 0.75 #rotation
CHECKPOINT_FOLDER = "./saved_model"

best_val_acc = 0
best_val_acc_loss = 0
train_accs=[]
train_losses=[]
val_accs=[]
val_losses=[]
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
    if i in DECAY_EPOCHS:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)

    model.train()
    print("Epoch %d:" %i)
    total_examples = 0
    correct_examples = 0
    train_loss = 0

    for batch_idx, (inputs, targets, rotations) in enumerate(train_loader):
        inputs, targets, rotations = inputs.to(device), targets.to(device), rotations.to(device) #rotation
        inputs, targets_a, targets_b,rotations_a,rotations_b, lam = mixup_data(inputs, targets, rotations,alpha, device)#mixup rotation

        outputs, rotation_outputs = model(inputs)
        #loss = criterion(outputs, targets) + LAMBDA * criterion(rotation_outputs, rotations) #rotation
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam)+ LAMBDA * mixup_criterion(criterion, rotation_outputs, rotations_a, rotations_b, lam) if i>=100 else mixup_criterion(criterion, rotation_outputs, rotations_a, rotations_b, lam)#mixup rotation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total_examples += targets.size(0)
        #correct_examples += predicted.eq(targets).sum().item()
        correct_examples += (lam * predicted.eq(targets_a.data).cpu().sum().float()+ (1 - lam) * predicted.eq(targets_b.data).cpu().sum().float())#mixup




    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
    train_accs.append(avg_acc)
    train_losses.append(avg_loss)


    model.eval()
    total_examples = 0
    correct_examples = 0

    val_loss = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs, _ = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item()
            _, predicted = outputs.max(1)
            total_examples += targets.size(0)
            correct_examples += predicted.eq(targets).sum().item()

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    val_accs.append(avg_acc)
    val_losses.append(avg_loss)

    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        best_val_acc_loss = avg_loss
        if not os.path.exists(CHECKPOINT_FOLDER):
            os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': model.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'combine.pth'))

    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f} with loss: {best_val_acc_loss:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.1800, Training accuracy: 0.0881
# Validation loss: 2.4655, Validation accuracy: 0.1165
# Saving ...
#
# Epoch 1:
# Training loss: 1.0742, Training accuracy: 0.0841
# Validation loss: 2.3782, Validation accuracy: 0.0912
#
# Epoch 2:
# Training loss: 1.0102, Training accuracy: 0.0850
# Validation loss: 2.3545, Validation accuracy: 0.0874
#
# Epoch 3:
# Training loss: 0.9504, Training accuracy: 0.0830
# Validation loss: 2.3906, Validation accuracy: 0.0932
#
# Epoch 4:
# Training loss: 0.9187, Training accuracy: 0.0847
# Validation loss: 2.4921, Validation accuracy: 0.1006
#
# Epoch 5:
# Training loss: 0.8898, Training accuracy: 0.0854
# Validation loss: 2.3734, Validation accuracy: 0.0690
#
# Epoch 6:
# Training loss: 0.8660, Training accuracy: 0.0819
# Validation loss: 2.3801, Validation accuracy: 0.0559
#
# Epoch 7:
# Training loss: 0.8519, Training accuracy: 0.0799
# Validation loss: 2.5025, Validation accuracy: 0.0651
#
# Epoch 8:
# Training loss: 0.8398, Training accuracy: 0.0833
# Validation loss: 2.4177, Validation accuracy: 0.0970
#
# Epoch 9:
# Training loss: 0.8161, Training accuracy: 0.0852
# Validation loss: 2.4543, Validation accuracy: 0.0704
#
# Epoch 10:
# Training loss: 0.8081, Training accuracy: 0.0828
# Validation loss: 2.4076, Validation accuracy: 0.0989
#
# Epoch 11:
# Training loss: 0.8055, Training accuracy: 0.0841
# Validation loss: 2.4143, Validation accuracy: 0.1038
#
# Epoch 12:
# Training loss: 0.7957, Training accuracy: 0.0859
# Validation loss: 2.3503, Validation accuracy: 0.0980
#
# Epoch 13:
# Training loss: 0.7876, Training accuracy: 0.0875
# Validation loss: 2.4425, Validation accuracy: 0.0884
#
# Epoch 14:
# Training loss: 0.7769, Training accuracy: 0.0845
# Validation loss: 2.3838, Validation accuracy: 0.0904
#
# Epoch 15:
# Training loss: 0.7773, Training accuracy: 0.0818
# Validation loss: 2.4068, Validation accuracy: 0.0981
#
# Epoch 16:
# Training loss: 0.7643, Training accuracy: 0.0788
# Validation loss: 2.4224, Validation accuracy: 0.0705
#
# Epoch 17:
# Training loss: 0.7732, Training accuracy: 0.0803
# Validation loss: 2.4361, Validation accuracy: 0.0904
#
# Epoch 18:
# Training loss: 0.7660, Training accuracy: 0.0797
# Validation loss: 2.3674, Validation accuracy: 0.0966
#
# Epoch 19:
# Training loss: 0.7543, Training accuracy: 0.0844
# Validation loss: 2.3577, Validation accuracy: 0.0983
#
# Epoch 20:
# Training loss: 0.7530, Training accuracy: 0.0812
# Validation loss: 2.3642, Validation accuracy: 0.1184
# Saving ...
#
# Epoch 21:
# Training loss: 0.7475, Training accuracy: 0.0803
# Validation loss: 2.4437, Validation accuracy: 0.1072
#
# Epoch 22:
# Training loss: 0.7520, Training accuracy: 0.0806
# Validation loss: 2.4561, Validation accuracy: 0.0965
#
# Epoch 23:
# Training loss: 0.7451, Training accuracy: 0.0800
# Validation loss: 2.3926, Validation accuracy: 0.1073
#
# Epoch 24:
# Training loss: 0.7465, Training accuracy: 0.0805
# Validation loss: 2.4242, Validation accuracy: 0.1036
#
# Epoch 25:
# Training loss: 0.7402, Training accuracy: 0.0816
# Validation loss: 2.3945, Validation accuracy: 0.0866
#
# Epoch 26:
# Training loss: 0.7319, Training accuracy: 0.0764
# Validation loss: 2.4035, Validation accuracy: 0.1008
#
# Epoch 27:
# Training loss: 0.7425, Training accuracy: 0.0776
# Validation loss: 2.4604, Validation accuracy: 0.0909
#
# Epoch 28:
# Training loss: 0.7427, Training accuracy: 0.0763
# Validation loss: 2.4163, Validation accuracy: 0.0856
#
# Epoch 29:
# Training loss: 0.7357, Training accuracy: 0.0741
# Validation loss: 2.3872, Validation accuracy: 0.0865
#
# Current learning rate has decayed to 0.020000
# Epoch 30:
# Training loss: 0.6643, Training accuracy: 0.0785
# Validation loss: 2.4015, Validation accuracy: 0.0851
#
# Epoch 31:
# Training loss: 0.6410, Training accuracy: 0.0785
# Validation loss: 2.4039, Validation accuracy: 0.0864
#
# Epoch 32:
# Training loss: 0.6360, Training accuracy: 0.0799
# Validation loss: 2.4097, Validation accuracy: 0.0882
#
# Epoch 33:
# Training loss: 0.6307, Training accuracy: 0.0815
# Validation loss: 2.4067, Validation accuracy: 0.0757
#
# Epoch 34:
# Training loss: 0.6335, Training accuracy: 0.0829
# Validation loss: 2.4173, Validation accuracy: 0.0994
#
# Epoch 35:
# Training loss: 0.6327, Training accuracy: 0.0827
# Validation loss: 2.4171, Validation accuracy: 0.0837
#
# Epoch 36:
# Training loss: 0.6371, Training accuracy: 0.0830
# Validation loss: 2.4416, Validation accuracy: 0.0960
#
# Epoch 37:
# Training loss: 0.6334, Training accuracy: 0.0846
# Validation loss: 2.3950, Validation accuracy: 0.0999
#
# Epoch 38:
# Training loss: 0.6318, Training accuracy: 0.0860
# Validation loss: 2.4289, Validation accuracy: 0.0906
#
# Epoch 39:
# Training loss: 0.6218, Training accuracy: 0.0820
# Validation loss: 2.4375, Validation accuracy: 0.0938
#
# Epoch 40:
# Training loss: 0.6192, Training accuracy: 0.0837
# Validation loss: 2.4247, Validation accuracy: 0.0928
#
# Epoch 41:
# Training loss: 0.6235, Training accuracy: 0.0849
# Validation loss: 2.4550, Validation accuracy: 0.0939
#
# Epoch 42:
# Training loss: 0.6277, Training accuracy: 0.0873
# Validation loss: 2.4563, Validation accuracy: 0.0948
#
# Epoch 43:
# Training loss: 0.6394, Training accuracy: 0.0893
# Validation loss: 2.3991, Validation accuracy: 0.0963
#
# Epoch 44:
# Training loss: 0.6266, Training accuracy: 0.0878
# Validation loss: 2.4245, Validation accuracy: 0.1011
#
# Epoch 45:
# Training loss: 0.6333, Training accuracy: 0.0880
# Validation loss: 2.4373, Validation accuracy: 0.1006
#
# Epoch 46:
# Training loss: 0.6229, Training accuracy: 0.0878
# Validation loss: 2.4451, Validation accuracy: 0.0995
#
# Epoch 47:
# Training loss: 0.6246, Training accuracy: 0.0909
# Validation loss: 2.4288, Validation accuracy: 0.0999
#
# Epoch 48:
# Training loss: 0.6403, Training accuracy: 0.0892
# Validation loss: 2.4218, Validation accuracy: 0.1082
#
# Epoch 49:
# Training loss: 0.6235, Training accuracy: 0.0910
# Validation loss: 2.4236, Validation accuracy: 0.0907
#
# Epoch 50:
# Training loss: 0.6143, Training accuracy: 0.0922
# Validation loss: 2.4207, Validation accuracy: 0.0978
#
# Epoch 51:
# Training loss: 0.6204, Training accuracy: 0.0926
# Validation loss: 2.4452, Validation accuracy: 0.0972
#
# Epoch 52:
# Training loss: 0.6171, Training accuracy: 0.0930
# Validation loss: 2.4176, Validation accuracy: 0.0969
#
# Epoch 53:
# Training loss: 0.6279, Training accuracy: 0.0912
# Validation loss: 2.3975, Validation accuracy: 0.0975
#
# Epoch 54:
# Training loss: 0.6216, Training accuracy: 0.0906
# Validation loss: 2.4269, Validation accuracy: 0.1045
#
# Epoch 55:
# Training loss: 0.6234, Training accuracy: 0.0922
# Validation loss: 2.3931, Validation accuracy: 0.1051
#
# Epoch 56:
# Training loss: 0.6169, Training accuracy: 0.0934
# Validation loss: 2.4418, Validation accuracy: 0.0984
#
# Epoch 57:
# Training loss: 0.6310, Training accuracy: 0.0943
# Validation loss: 2.4144, Validation accuracy: 0.1195
# Saving ...
#
# Epoch 58:
# Training loss: 0.6172, Training accuracy: 0.0955
# Validation loss: 2.4015, Validation accuracy: 0.1056
#
# Epoch 59:
# Training loss: 0.6250, Training accuracy: 0.0929
# Validation loss: 2.3748, Validation accuracy: 0.1069
#
# Current learning rate has decayed to 0.004000
# Epoch 60:
# Training loss: 0.5696, Training accuracy: 0.0891
# Validation loss: 2.4039, Validation accuracy: 0.1057
#
# Epoch 61:
# Training loss: 0.5798, Training accuracy: 0.0920
# Validation loss: 2.4055, Validation accuracy: 0.1090
#
# Epoch 62:
# Training loss: 0.5620, Training accuracy: 0.0928
# Validation loss: 2.4392, Validation accuracy: 0.1050
#
# Epoch 63:
# Training loss: 0.5670, Training accuracy: 0.0941
# Validation loss: 2.4010, Validation accuracy: 0.1101
#
# Epoch 64:
# Training loss: 0.5740, Training accuracy: 0.0950
# Validation loss: 2.4151, Validation accuracy: 0.1056
#
# Epoch 65:
# Training loss: 0.5748, Training accuracy: 0.0951
# Validation loss: 2.4218, Validation accuracy: 0.1068
#
# Epoch 66:
# Training loss: 0.5755, Training accuracy: 0.0947
# Validation loss: 2.4082, Validation accuracy: 0.1055
#
# Epoch 67:
# Training loss: 0.5764, Training accuracy: 0.0957
# Validation loss: 2.4278, Validation accuracy: 0.1092
#
# Epoch 68:
# Training loss: 0.5624, Training accuracy: 0.0952
# Validation loss: 2.4578, Validation accuracy: 0.1063
#
# Epoch 69:
# Training loss: 0.5598, Training accuracy: 0.0957
# Validation loss: 2.4307, Validation accuracy: 0.1059
#
# Epoch 70:
# Training loss: 0.5608, Training accuracy: 0.0955
# Validation loss: 2.4076, Validation accuracy: 0.1058
#
# Epoch 71:
# Training loss: 0.5650, Training accuracy: 0.0956
# Validation loss: 2.4439, Validation accuracy: 0.1100
#
# Epoch 72:
# Training loss: 0.5568, Training accuracy: 0.0959
# Validation loss: 2.4113, Validation accuracy: 0.1063
#
# Epoch 73:
# Training loss: 0.5600, Training accuracy: 0.0949
# Validation loss: 2.4102, Validation accuracy: 0.1037
#
# Epoch 74:
# Training loss: 0.5641, Training accuracy: 0.0963
# Validation loss: 2.4219, Validation accuracy: 0.1127
#
# Epoch 75:
# Training loss: 0.5603, Training accuracy: 0.0957
# Validation loss: 2.3912, Validation accuracy: 0.1096
#
# Epoch 76:
# Training loss: 0.5640, Training accuracy: 0.0963
# Validation loss: 2.4340, Validation accuracy: 0.1088
#
# Epoch 77:
# Training loss: 0.5577, Training accuracy: 0.0966
# Validation loss: 2.4148, Validation accuracy: 0.1065
#
# Epoch 78:
# Training loss: 0.5615, Training accuracy: 0.0955
# Validation loss: 2.4216, Validation accuracy: 0.1073
#
# Epoch 79:
# Training loss: 0.5605, Training accuracy: 0.0961
# Validation loss: 2.4004, Validation accuracy: 0.1061
#
# Epoch 80:
# Training loss: 0.5559, Training accuracy: 0.0967
# Validation loss: 2.4092, Validation accuracy: 0.1054
#
# Epoch 81:
# Training loss: 0.5542, Training accuracy: 0.0965
# Validation loss: 2.4654, Validation accuracy: 0.1069
#
# Epoch 82:
# Training loss: 0.5547, Training accuracy: 0.0965
# Validation loss: 2.4053, Validation accuracy: 0.1062
#
# Epoch 83:
# Training loss: 0.5495, Training accuracy: 0.0961
# Validation loss: 2.3869, Validation accuracy: 0.1127
#
# Epoch 84:
# Training loss: 0.5500, Training accuracy: 0.0970
# Validation loss: 2.4166, Validation accuracy: 0.1069
#
# Epoch 85:
# Training loss: 0.5446, Training accuracy: 0.0972
# Validation loss: 2.4076, Validation accuracy: 0.1098
#
# Epoch 86:
# Training loss: 0.5513, Training accuracy: 0.0972
# Validation loss: 2.4044, Validation accuracy: 0.1087
#
# Epoch 87:
# Training loss: 0.5628, Training accuracy: 0.0974
# Validation loss: 2.3965, Validation accuracy: 0.1080
#
# Epoch 88:
# Training loss: 0.5507, Training accuracy: 0.0969
# Validation loss: 2.4065, Validation accuracy: 0.1083
#
# Epoch 89:
# Training loss: 0.5568, Training accuracy: 0.0965
# Validation loss: 2.3962, Validation accuracy: 0.1090
#
# Epoch 90:
# Training loss: 0.5541, Training accuracy: 0.0969
# Validation loss: 2.4273, Validation accuracy: 0.1114
#
# Epoch 91:
# Training loss: 0.5655, Training accuracy: 0.0973
# Validation loss: 2.4275, Validation accuracy: 0.1029
#
# Epoch 92:
# Training loss: 0.5516, Training accuracy: 0.0980
# Validation loss: 2.4349, Validation accuracy: 0.1103
#
# Epoch 93:
# Training loss: 0.5604, Training accuracy: 0.0977
# Validation loss: 2.4261, Validation accuracy: 0.1115
#
# Epoch 94:
# Training loss: 0.5495, Training accuracy: 0.0980
# Validation loss: 2.4141, Validation accuracy: 0.1062
#
# Epoch 95:
# Training loss: 0.5586, Training accuracy: 0.0972
# Validation loss: 2.4525, Validation accuracy: 0.1129
#
# Epoch 96:
# Training loss: 0.5404, Training accuracy: 0.0975
# Validation loss: 2.4232, Validation accuracy: 0.1071
#
# Epoch 97:
# Training loss: 0.5535, Training accuracy: 0.0979
# Validation loss: 2.4062, Validation accuracy: 0.1050
#
# Epoch 98:
# Training loss: 0.5527, Training accuracy: 0.0982
# Validation loss: 2.4196, Validation accuracy: 0.1116
#
# Epoch 99:
# Training loss: 0.5680, Training accuracy: 0.0983
# Validation loss: 2.3932, Validation accuracy: 0.1068
#
# Current learning rate has decayed to 0.000800
# Epoch 100:
# Training loss: 2.3069, Training accuracy: 0.3408
# Validation loss: 1.2913, Validation accuracy: 0.5413
# Saving ...
#
# Epoch 101:
# Training loss: 1.8917, Training accuracy: 0.5060
# Validation loss: 1.0421, Validation accuracy: 0.6258
# Saving ...
#
# Epoch 102:
# Training loss: 1.7574, Training accuracy: 0.5487
# Validation loss: 0.9420, Validation accuracy: 0.6666
# Saving ...
#
# Epoch 103:
# Training loss: 1.6997, Training accuracy: 0.5718
# Validation loss: 0.9090, Validation accuracy: 0.6867
# Saving ...
#
# Epoch 104:
# Training loss: 1.6810, Training accuracy: 0.5829
# Validation loss: 0.8583, Validation accuracy: 0.7065
# Saving ...
#
# Epoch 105:
# Training loss: 1.6398, Training accuracy: 0.5952
# Validation loss: 0.7828, Validation accuracy: 0.7256
# Saving ...
#
# Epoch 106:
# Training loss: 1.5966, Training accuracy: 0.6098
# Validation loss: 0.7487, Validation accuracy: 0.7413
# Saving ...
#
# Epoch 107:
# Training loss: 1.5916, Training accuracy: 0.6133
# Validation loss: 0.7015, Validation accuracy: 0.7544
# Saving ...
#
# Epoch 108:
# Training loss: 1.5790, Training accuracy: 0.6200
# Validation loss: 0.6866, Validation accuracy: 0.7603
# Saving ...
#
# Epoch 109:
# Training loss: 1.5398, Training accuracy: 0.6297
# Validation loss: 0.6993, Validation accuracy: 0.7602
#
# Epoch 110:
# Training loss: 1.5369, Training accuracy: 0.6325
# Validation loss: 0.6936, Validation accuracy: 0.7604
# Saving ...
#
# Epoch 111:
# Training loss: 1.5478, Training accuracy: 0.6321
# Validation loss: 0.6485, Validation accuracy: 0.7741
# Saving ...
#
# Epoch 112:
# Training loss: 1.5248, Training accuracy: 0.6394
# Validation loss: 0.6448, Validation accuracy: 0.7767
# Saving ...
#
# Epoch 113:
# Training loss: 1.5371, Training accuracy: 0.6372
# Validation loss: 0.6224, Validation accuracy: 0.7844
# Saving ...
#
# Epoch 114:
# Training loss: 1.5358, Training accuracy: 0.6390
# Validation loss: 0.6556, Validation accuracy: 0.7764
#
# Epoch 115:
# Training loss: 1.5234, Training accuracy: 0.6425
# Validation loss: 0.6158, Validation accuracy: 0.7864
# Saving ...
#
# Epoch 116:
# Training loss: 1.4777, Training accuracy: 0.6520
# Validation loss: 0.6338, Validation accuracy: 0.7855
#
# Epoch 117:
# Training loss: 1.4798, Training accuracy: 0.6540
# Validation loss: 0.5959, Validation accuracy: 0.7939
# Saving ...
#
# Epoch 118:
# Training loss: 1.4984, Training accuracy: 0.6515
# Validation loss: 0.6497, Validation accuracy: 0.7787
#
# Epoch 119:
# Training loss: 1.4948, Training accuracy: 0.6537
# Validation loss: 0.6015, Validation accuracy: 0.7951
# Saving ...
#
# Epoch 120:
# Training loss: 1.4793, Training accuracy: 0.6572
# Validation loss: 0.6097, Validation accuracy: 0.7942
#
# Epoch 121:
# Training loss: 1.4757, Training accuracy: 0.6588
# Validation loss: 0.5757, Validation accuracy: 0.8032
# Saving ...
#
# Epoch 122:
# Training loss: 1.4529, Training accuracy: 0.6638
# Validation loss: 0.5739, Validation accuracy: 0.8000
#
# Epoch 123:
# Training loss: 1.4834, Training accuracy: 0.6580
# Validation loss: 0.5789, Validation accuracy: 0.8034
# Saving ...
#
# Epoch 124:
# Training loss: 1.4935, Training accuracy: 0.6575
# Validation loss: 0.5689, Validation accuracy: 0.8060
# Saving ...
#
# Epoch 125:
# Training loss: 1.4566, Training accuracy: 0.6665
# Validation loss: 0.5723, Validation accuracy: 0.8070
# Saving ...
#
# Epoch 126:
# Training loss: 1.4791, Training accuracy: 0.6603
# Validation loss: 0.5491, Validation accuracy: 0.8099
# Saving ...
#
# Epoch 127:
# Training loss: 1.4475, Training accuracy: 0.6681
# Validation loss: 0.5855, Validation accuracy: 0.8093
#
# Epoch 128:
# Training loss: 1.4352, Training accuracy: 0.6698
# Validation loss: 0.5482, Validation accuracy: 0.8147
# Saving ...
#
# Epoch 129:
# Training loss: 1.4588, Training accuracy: 0.6673
# Validation loss: 0.5664, Validation accuracy: 0.8115
#
# Epoch 130:
# Training loss: 1.4344, Training accuracy: 0.6718
# Validation loss: 0.5531, Validation accuracy: 0.8175
# Saving ...
#
# Epoch 131:
# Training loss: 1.4283, Training accuracy: 0.6732
# Validation loss: 0.5777, Validation accuracy: 0.8104
#
# Epoch 132:
# Training loss: 1.4579, Training accuracy: 0.6680
# Validation loss: 0.5269, Validation accuracy: 0.8163
#
# Epoch 133:
# Training loss: 1.4250, Training accuracy: 0.6746
# Validation loss: 0.5759, Validation accuracy: 0.8123
#
# Epoch 134:
# Training loss: 1.4415, Training accuracy: 0.6727
# Validation loss: 0.5498, Validation accuracy: 0.8163
#
# Epoch 135:
# Training loss: 1.4259, Training accuracy: 0.6770
# Validation loss: 0.5482, Validation accuracy: 0.8193
# Saving ...
#
# Epoch 136:
# Training loss: 1.4347, Training accuracy: 0.6727
# Validation loss: 0.5191, Validation accuracy: 0.8252
# Saving ...
#
# Epoch 137:
# Training loss: 1.4193, Training accuracy: 0.6791
# Validation loss: 0.5195, Validation accuracy: 0.8222
#
# Epoch 138:
# Training loss: 1.4504, Training accuracy: 0.6713
# Validation loss: 0.5771, Validation accuracy: 0.8179
#
# Epoch 139:
# Training loss: 1.4251, Training accuracy: 0.6773
# Validation loss: 0.5172, Validation accuracy: 0.8254
# Saving ...
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.8254 with loss: 0.5172

# %% [markdown]
# ## 4.

# %%
import matplotlib.pyplot as plt
plt.plot(range(140),train_accs,label='train_accuracy')
plt.plot(range(140),val_accs,label='validation_accuracy')
plt.xlabel('episode')
plt.ylabel('accuracy')
plt.title('Accuracy vs Episode (combine)')
plt.legend()
plt.show()

# %%
plt.plot(range(140),train_losses,label='train_loss')
plt.plot(range(140),val_losses,label='validation_loss')
plt.xlabel('episode')
plt.ylabel('loss')
plt.title('Loss vs Episode (combine)')
plt.legend()
plt.show()
