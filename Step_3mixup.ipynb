# %% [markdown]
# # Improved Regularization of Convolutional Neural Networks (Step-3mixup)

# %% [markdown]
# ## 1. Resnet-20

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

# %%
def _weights_init(m):
    """
        Initialization of CNN weights
    """
    classname = m.__class__.__name__
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight)

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet20(nn.Module):
    def __init__(self):
        super(ResNet20, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)

        self.layer1 = self.blocks(16, 16, 3, stride=1)
        self.layer2 = self.blocks(16, 32, 3, stride=2)
        self.layer3 = self.blocks(32, 64, 3, stride=2)
        self.fc = nn.Linear(64, 10)
        self.apply(_weights_init)

    def blocks(self, in_channels, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for i in strides:
            layers.append(ResidualBlock(in_channels, out_channels, i))
            in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

# %% [markdown]
# ## 2. Data Processing

# %%
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader


normalize = transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],
                                     std=[0.2023, 0.1994, 0.2010])


train_loader = DataLoader(
        datasets.CIFAR10(root='./data', train=True, transform=transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.RandomCrop(32, 4),
            transforms.ToTensor(),
            normalize,
        ]), download=True),
        batch_size=128, shuffle=True,
        num_workers=4, pin_memory=True)

val_loader = DataLoader(
        datasets.CIFAR10(root='./data', train=False, transform=transforms.Compose([
            transforms.ToTensor(),
            normalize,
        ])),
        batch_size=128, shuffle=False,
        num_workers=4, pin_memory=True)
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## 3. Model Training

# %%
def mixup_data(x, y, alpha, device):
    '''Returns mixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    index = torch.randperm(batch_size).to(device)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
import torch.optim as optim

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = ResNet20().to(device)

INITIAL_LR = 0.1
MOMENTUM = 0.9
REG = 1e-4
alpha = 0.15#mixup

criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)

# %%
import os
EPOCHS = 200
DECAY_EPOCHS = [60,120,160]#decay epoch change according to essay
DECAY = 0.2

CHECKPOINT_FOLDER = "./saved_model"

best_val_acc = 0
best_val_acc_loss = 0
train_accs=[]
train_losses=[]
val_accs=[]
val_losses=[]
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
    if i in DECAY_EPOCHS:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)

    model.train()
    print("Epoch %d:" %i)
    total_examples = 0
    correct_examples = 0
    train_loss = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        inputs, targets_a, targets_b, lam = mixup_data(inputs, targets,alpha, device)#mixup

        outputs = model(inputs)
        #loss = criterion(outputs, targets)
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam)#mixup
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total_examples += targets.size(0)
        #correct_examples += predicted.eq(targets).sum().item()
        correct_examples += (lam * predicted.eq(targets_a.data).cpu().sum().float()+ (1 - lam) * predicted.eq(targets_b.data).cpu().sum().float())#mixup


    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
    train_accs.append(avg_acc)
    train_losses.append(avg_loss)


    model.eval()
    total_examples = 0
    correct_examples = 0

    val_loss = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item()
            _, predicted = outputs.max(1)
            total_examples += targets.size(0)
            correct_examples += predicted.eq(targets).sum().item()

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    val_accs.append(avg_acc)
    val_losses.append(avg_loss)

    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        best_val_acc_loss = avg_loss
        if not os.path.exists(CHECKPOINT_FOLDER):
            os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': model.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'mixup.pth'))

    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f} with loss: {best_val_acc_loss:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.6815, Training accuracy: 0.3988
# Validation loss: 1.2359, Validation accuracy: 0.5504
# Saving ...
#
# Epoch 1:
# Training loss: 1.2675, Training accuracy: 0.5756
# Validation loss: 0.9625, Validation accuracy: 0.6677
# Saving ...
#
# Epoch 2:
# Training loss: 1.1094, Training accuracy: 0.6448
# Validation loss: 0.9496, Validation accuracy: 0.6708
# Saving ...
#
# Epoch 3:
# Training loss: 1.0234, Training accuracy: 0.6775
# Validation loss: 0.9051, Validation accuracy: 0.6950
# Saving ...
#
# Epoch 4:
# Training loss: 0.9568, Training accuracy: 0.7040
# Validation loss: 0.7347, Validation accuracy: 0.7563
# Saving ...
#
# Epoch 5:
# Training loss: 0.9037, Training accuracy: 0.7247
# Validation loss: 0.7759, Validation accuracy: 0.7422
#
# Epoch 6:
# Training loss: 0.8267, Training accuracy: 0.7469
# Validation loss: 0.7315, Validation accuracy: 0.7567
# Saving ...
#
# Epoch 7:
# Training loss: 0.8561, Training accuracy: 0.7423
# Validation loss: 0.7178, Validation accuracy: 0.7550
#
# Epoch 8:
# Training loss: 0.8071, Training accuracy: 0.7491
# Validation loss: 0.5823, Validation accuracy: 0.8124
# Saving ...
#
# Epoch 9:
# Training loss: 0.8000, Training accuracy: 0.7559
# Validation loss: 0.8353, Validation accuracy: 0.7246
#
# Epoch 10:
# Training loss: 0.7887, Training accuracy: 0.7595
# Validation loss: 0.6894, Validation accuracy: 0.7830
#
# Epoch 11:
# Training loss: 0.7358, Training accuracy: 0.7768
# Validation loss: 0.5491, Validation accuracy: 0.8143
# Saving ...
#
# Epoch 12:
# Training loss: 0.7385, Training accuracy: 0.7772
# Validation loss: 0.5321, Validation accuracy: 0.8257
# Saving ...
#
# Epoch 13:
# Training loss: 0.7365, Training accuracy: 0.7783
# Validation loss: 0.5153, Validation accuracy: 0.8287
# Saving ...
#
# Epoch 14:
# Training loss: 0.7080, Training accuracy: 0.7883
# Validation loss: 0.5267, Validation accuracy: 0.8277
#
# Epoch 15:
# Training loss: 0.7270, Training accuracy: 0.7803
# Validation loss: 0.5127, Validation accuracy: 0.8284
#
# Epoch 16:
# Training loss: 0.6977, Training accuracy: 0.7928
# Validation loss: 0.5824, Validation accuracy: 0.8013
#
# Epoch 17:
# Training loss: 0.6940, Training accuracy: 0.7924
# Validation loss: 0.4995, Validation accuracy: 0.8281
#
# Epoch 18:
# Training loss: 0.6749, Training accuracy: 0.7988
# Validation loss: 0.5777, Validation accuracy: 0.8094
#
# Epoch 19:
# Training loss: 0.6827, Training accuracy: 0.7969
# Validation loss: 0.4831, Validation accuracy: 0.8438
# Saving ...
#
# Epoch 20:
# Training loss: 0.6720, Training accuracy: 0.7985
# Validation loss: 0.5158, Validation accuracy: 0.8328
#
# Epoch 21:
# Training loss: 0.6699, Training accuracy: 0.7978
# Validation loss: 0.5375, Validation accuracy: 0.8140
#
# Epoch 22:
# Training loss: 0.6450, Training accuracy: 0.8083
# Validation loss: 0.4903, Validation accuracy: 0.8359
#
# Epoch 23:
# Training loss: 0.6539, Training accuracy: 0.8126
# Validation loss: 0.5259, Validation accuracy: 0.8286
#
# Epoch 24:
# Training loss: 0.6376, Training accuracy: 0.8110
# Validation loss: 0.4970, Validation accuracy: 0.8331
#
# Epoch 25:
# Training loss: 0.6409, Training accuracy: 0.8116
# Validation loss: 0.4664, Validation accuracy: 0.8472
# Saving ...
#
# Epoch 26:
# Training loss: 0.6454, Training accuracy: 0.8094
# Validation loss: 0.5408, Validation accuracy: 0.8402
#
# Epoch 27:
# Training loss: 0.6376, Training accuracy: 0.8138
# Validation loss: 0.4981, Validation accuracy: 0.8386
#
# Epoch 28:
# Training loss: 0.6036, Training accuracy: 0.8233
# Validation loss: 0.4935, Validation accuracy: 0.8424
#
# Epoch 29:
# Training loss: 0.6293, Training accuracy: 0.8153
# Validation loss: 0.4427, Validation accuracy: 0.8546
# Saving ...
#
# Epoch 30:
# Training loss: 0.6685, Training accuracy: 0.8073
# Validation loss: 0.4980, Validation accuracy: 0.8328
#
# Epoch 31:
# Training loss: 0.6200, Training accuracy: 0.8202
# Validation loss: 0.4737, Validation accuracy: 0.8468
#
# Epoch 32:
# Training loss: 0.6032, Training accuracy: 0.8256
# Validation loss: 0.4245, Validation accuracy: 0.8589
# Saving ...
#
# Epoch 33:
# Training loss: 0.6079, Training accuracy: 0.8233
# Validation loss: 0.4518, Validation accuracy: 0.8522
#
# Epoch 34:
# Training loss: 0.5976, Training accuracy: 0.8257
# Validation loss: 0.4270, Validation accuracy: 0.8586
#
# Epoch 35:
# Training loss: 0.6620, Training accuracy: 0.8088
# Validation loss: 0.4701, Validation accuracy: 0.8490
#
# Epoch 36:
# Training loss: 0.6376, Training accuracy: 0.8153
# Validation loss: 0.4684, Validation accuracy: 0.8492
#
# Epoch 37:
# Training loss: 0.6587, Training accuracy: 0.8092
# Validation loss: 0.5328, Validation accuracy: 0.8295
#
# Epoch 38:
# Training loss: 0.6265, Training accuracy: 0.8170
# Validation loss: 0.4973, Validation accuracy: 0.8373
#
# Epoch 39:
# Training loss: 0.5956, Training accuracy: 0.8281
# Validation loss: 0.4293, Validation accuracy: 0.8573
#
# Epoch 40:
# Training loss: 0.6154, Training accuracy: 0.8223
# Validation loss: 0.4874, Validation accuracy: 0.8466
#
# Epoch 41:
# Training loss: 0.5973, Training accuracy: 0.8286
# Validation loss: 0.5884, Validation accuracy: 0.8079
#
# Epoch 42:
# Training loss: 0.5753, Training accuracy: 0.8334
# Validation loss: 0.5175, Validation accuracy: 0.8289
#
# Epoch 43:
# Training loss: 0.5479, Training accuracy: 0.8410
# Validation loss: 0.4350, Validation accuracy: 0.8535
#
# Epoch 44:
# Training loss: 0.6155, Training accuracy: 0.8192
# Validation loss: 0.4512, Validation accuracy: 0.8548
#
# Epoch 45:
# Training loss: 0.6479, Training accuracy: 0.8133
# Validation loss: 0.4446, Validation accuracy: 0.8564
#
# Epoch 46:
# Training loss: 0.5868, Training accuracy: 0.8296
# Validation loss: 0.3810, Validation accuracy: 0.8793
# Saving ...
#
# Epoch 47:
# Training loss: 0.6005, Training accuracy: 0.8268
# Validation loss: 0.3991, Validation accuracy: 0.8720
#
# Epoch 48:
# Training loss: 0.6548, Training accuracy: 0.8104
# Validation loss: 0.4400, Validation accuracy: 0.8572
#
# Epoch 49:
# Training loss: 0.5920, Training accuracy: 0.8288
# Validation loss: 0.5043, Validation accuracy: 0.8352
#
# Epoch 50:
# Training loss: 0.6049, Training accuracy: 0.8269
# Validation loss: 0.4220, Validation accuracy: 0.8590
#
# Epoch 51:
# Training loss: 0.6438, Training accuracy: 0.8138
# Validation loss: 0.4843, Validation accuracy: 0.8418
#
# Epoch 52:
# Training loss: 0.5852, Training accuracy: 0.8276
# Validation loss: 0.4263, Validation accuracy: 0.8652
#
# Epoch 53:
# Training loss: 0.5808, Training accuracy: 0.8327
# Validation loss: 0.3933, Validation accuracy: 0.8728
#
# Epoch 54:
# Training loss: 0.5776, Training accuracy: 0.8365
# Validation loss: 0.4587, Validation accuracy: 0.8511
#
# Epoch 55:
# Training loss: 0.5842, Training accuracy: 0.8327
# Validation loss: 0.4970, Validation accuracy: 0.8395
#
# Epoch 56:
# Training loss: 0.5943, Training accuracy: 0.8270
# Validation loss: 0.4387, Validation accuracy: 0.8545
#
# Epoch 57:
# Training loss: 0.5750, Training accuracy: 0.8341
# Validation loss: 0.4049, Validation accuracy: 0.8705
#
# Epoch 58:
# Training loss: 0.5862, Training accuracy: 0.8293
# Validation loss: 0.4084, Validation accuracy: 0.8798
# Saving ...
#
# Epoch 59:
# Training loss: 0.6056, Training accuracy: 0.8367
# Validation loss: 0.4049, Validation accuracy: 0.8729
#
# Current learning rate has decayed to 0.020000
# Epoch 60:
# Training loss: 0.5625, Training accuracy: 0.8608
# Validation loss: 0.3024, Validation accuracy: 0.9103
# Saving ...
#
# Epoch 61:
# Training loss: 0.5354, Training accuracy: 0.8699
# Validation loss: 0.3064, Validation accuracy: 0.9131
# Saving ...
#
# Epoch 62:
# Training loss: 0.5147, Training accuracy: 0.8735
# Validation loss: 0.2796, Validation accuracy: 0.9144
# Saving ...
#
# Epoch 63:
# Training loss: 0.5077, Training accuracy: 0.8737
# Validation loss: 0.2896, Validation accuracy: 0.9117
#
# Epoch 64:
# Training loss: 0.5512, Training accuracy: 0.8665
# Validation loss: 0.3133, Validation accuracy: 0.9127
#
# Epoch 65:
# Training loss: 0.4636, Training accuracy: 0.8840
# Validation loss: 0.2858, Validation accuracy: 0.9122
#
# Epoch 66:
# Training loss: 0.5017, Training accuracy: 0.8742
# Validation loss: 0.2813, Validation accuracy: 0.9111
#
# Epoch 67:
# Training loss: 0.5103, Training accuracy: 0.8638
# Validation loss: 0.3012, Validation accuracy: 0.9127
#
# Epoch 68:
# Training loss: 0.4391, Training accuracy: 0.8837
# Validation loss: 0.3012, Validation accuracy: 0.9083
#
# Epoch 69:
# Training loss: 0.4802, Training accuracy: 0.8727
# Validation loss: 0.3303, Validation accuracy: 0.9132
#
# Epoch 70:
# Training loss: 0.4377, Training accuracy: 0.8838
# Validation loss: 0.2873, Validation accuracy: 0.9098
#
# Epoch 71:
# Training loss: 0.4977, Training accuracy: 0.8691
# Validation loss: 0.2955, Validation accuracy: 0.9104
#
# Epoch 72:
# Training loss: 0.4671, Training accuracy: 0.8744
# Validation loss: 0.2999, Validation accuracy: 0.9129
#
# Epoch 73:
# Training loss: 0.5053, Training accuracy: 0.8621
# Validation loss: 0.3149, Validation accuracy: 0.9113
#
# Epoch 74:
# Training loss: 0.4297, Training accuracy: 0.8852
# Validation loss: 0.2901, Validation accuracy: 0.9070
#
# Epoch 75:
# Training loss: 0.4423, Training accuracy: 0.8825
# Validation loss: 0.2887, Validation accuracy: 0.9108
#
# Epoch 76:
# Training loss: 0.4380, Training accuracy: 0.8864
# Validation loss: 0.2914, Validation accuracy: 0.9110
#
# Epoch 77:
# Training loss: 0.4273, Training accuracy: 0.8877
# Validation loss: 0.2855, Validation accuracy: 0.9132
#
# Epoch 78:
# Training loss: 0.4557, Training accuracy: 0.8772
# Validation loss: 0.2820, Validation accuracy: 0.9122
#
# Epoch 79:
# Training loss: 0.4591, Training accuracy: 0.8781
# Validation loss: 0.2897, Validation accuracy: 0.9117
#
# Epoch 80:
# Training loss: 0.4416, Training accuracy: 0.8839
# Validation loss: 0.2977, Validation accuracy: 0.9089
#
# Epoch 81:
# Training loss: 0.4814, Training accuracy: 0.8723
# Validation loss: 0.2919, Validation accuracy: 0.9114
#
# Epoch 82:
# Training loss: 0.4610, Training accuracy: 0.8755
# Validation loss: 0.2980, Validation accuracy: 0.9082
#
# Epoch 83:
# Training loss: 0.4901, Training accuracy: 0.8696
# Validation loss: 0.2938, Validation accuracy: 0.9071
#
# Epoch 84:
# Training loss: 0.4329, Training accuracy: 0.8850
# Validation loss: 0.3114, Validation accuracy: 0.9054
#
# Epoch 85:
# Training loss: 0.4567, Training accuracy: 0.8816
# Validation loss: 0.3105, Validation accuracy: 0.9068
#
# Epoch 86:
# Training loss: 0.4424, Training accuracy: 0.8826
# Validation loss: 0.2993, Validation accuracy: 0.9113
#
# Epoch 87:
# Training loss: 0.4238, Training accuracy: 0.8879
# Validation loss: 0.3093, Validation accuracy: 0.9042
#
# Epoch 88:
# Training loss: 0.4687, Training accuracy: 0.8764
# Validation loss: 0.3137, Validation accuracy: 0.9122
#
# Epoch 89:
# Training loss: 0.4263, Training accuracy: 0.8895
# Validation loss: 0.3093, Validation accuracy: 0.9071
#
# Epoch 90:
# Training loss: 0.4207, Training accuracy: 0.8913
# Validation loss: 0.3165, Validation accuracy: 0.9021
#
# Epoch 91:
# Training loss: 0.4593, Training accuracy: 0.8795
# Validation loss: 0.3072, Validation accuracy: 0.9046
#
# Epoch 92:
# Training loss: 0.4085, Training accuracy: 0.8963
# Validation loss: 0.2910, Validation accuracy: 0.9109
#
# Epoch 93:
# Training loss: 0.4224, Training accuracy: 0.8929
# Validation loss: 0.3042, Validation accuracy: 0.9094
#
# Epoch 94:
# Training loss: 0.4560, Training accuracy: 0.8781
# Validation loss: 0.3047, Validation accuracy: 0.9064
#
# Epoch 95:
# Training loss: 0.4385, Training accuracy: 0.8858
# Validation loss: 0.3567, Validation accuracy: 0.9032
#
# Epoch 96:
# Training loss: 0.4295, Training accuracy: 0.8860
# Validation loss: 0.3259, Validation accuracy: 0.9065
#
# Epoch 97:
# Training loss: 0.4243, Training accuracy: 0.8877
# Validation loss: 0.3511, Validation accuracy: 0.8975
#
# Epoch 98:
# Training loss: 0.4509, Training accuracy: 0.8846
# Validation loss: 0.3188, Validation accuracy: 0.9057
#
# Epoch 99:
# Training loss: 0.4372, Training accuracy: 0.8868
# Validation loss: 0.3075, Validation accuracy: 0.9086
#
# Epoch 100:
# Training loss: 0.4562, Training accuracy: 0.8791
# Validation loss: 0.3261, Validation accuracy: 0.9011
#
# Epoch 101:
# Training loss: 0.4331, Training accuracy: 0.8861
# Validation loss: 0.2917, Validation accuracy: 0.9078
#
# Epoch 102:
# Training loss: 0.4501, Training accuracy: 0.8812
# Validation loss: 0.3155, Validation accuracy: 0.9040
#
# Epoch 103:
# Training loss: 0.4230, Training accuracy: 0.8853
# Validation loss: 0.3196, Validation accuracy: 0.9070
#
# Epoch 104:
# Training loss: 0.4726, Training accuracy: 0.8748
# Validation loss: 0.3439, Validation accuracy: 0.8987
#
# Epoch 105:
# Training loss: 0.4483, Training accuracy: 0.8831
# Validation loss: 0.3739, Validation accuracy: 0.8899
#
# Epoch 106:
# Training loss: 0.4195, Training accuracy: 0.8919
# Validation loss: 0.2982, Validation accuracy: 0.9076
#
# Epoch 107:
# Training loss: 0.4658, Training accuracy: 0.8766
# Validation loss: 0.3115, Validation accuracy: 0.9085
#
# Epoch 108:
# Training loss: 0.4750, Training accuracy: 0.8702
# Validation loss: 0.2964, Validation accuracy: 0.9072
#
# Epoch 109:
# Training loss: 0.4385, Training accuracy: 0.8813
# Validation loss: 0.3448, Validation accuracy: 0.8996
#
# Epoch 110:
# Training loss: 0.4779, Training accuracy: 0.8737
# Validation loss: 0.3219, Validation accuracy: 0.9046
#
# Epoch 111:
# Training loss: 0.4557, Training accuracy: 0.8812
# Validation loss: 0.3083, Validation accuracy: 0.9069
#
# Epoch 112:
# Training loss: 0.4174, Training accuracy: 0.8901
# Validation loss: 0.3422, Validation accuracy: 0.8984
#
# Epoch 113:
# Training loss: 0.4218, Training accuracy: 0.8901
# Validation loss: 0.3391, Validation accuracy: 0.8965
#
# Epoch 114:
# Training loss: 0.4531, Training accuracy: 0.8807
# Validation loss: 0.3293, Validation accuracy: 0.9066
#
# Epoch 115:
# Training loss: 0.4689, Training accuracy: 0.8761
# Validation loss: 0.3044, Validation accuracy: 0.9072
#
# Epoch 116:
# Training loss: 0.4500, Training accuracy: 0.8806
# Validation loss: 0.3357, Validation accuracy: 0.9072
#
# Epoch 117:
# Training loss: 0.4189, Training accuracy: 0.8894
# Validation loss: 0.3473, Validation accuracy: 0.9055
#
# Epoch 118:
# Training loss: 0.5005, Training accuracy: 0.8667
# Validation loss: 0.2937, Validation accuracy: 0.9096
#
# Epoch 119:
# Training loss: 0.4343, Training accuracy: 0.8869
# Validation loss: 0.3088, Validation accuracy: 0.9040
#
# Current learning rate has decayed to 0.004000
# Epoch 120:
# Training loss: 0.4001, Training accuracy: 0.8951
# Validation loss: 0.2652, Validation accuracy: 0.9161
# Saving ...
#
# Epoch 121:
# Training loss: 0.4266, Training accuracy: 0.8904
# Validation loss: 0.3131, Validation accuracy: 0.9164
# Saving ...
#
# Epoch 122:
# Training loss: 0.3662, Training accuracy: 0.9090
# Validation loss: 0.2689, Validation accuracy: 0.9185
# Saving ...
#
# Epoch 123:
# Training loss: 0.3652, Training accuracy: 0.9071
# Validation loss: 0.2851, Validation accuracy: 0.9178
#
# Epoch 124:
# Training loss: 0.3530, Training accuracy: 0.9130
# Validation loss: 0.2625, Validation accuracy: 0.9181
#
# Epoch 125:
# Training loss: 0.3949, Training accuracy: 0.9014
# Validation loss: 0.2567, Validation accuracy: 0.9188
# Saving ...
#
# Epoch 126:
# Training loss: 0.3551, Training accuracy: 0.9119
# Validation loss: 0.2628, Validation accuracy: 0.9182
#
# Epoch 127:
# Training loss: 0.4250, Training accuracy: 0.8900
# Validation loss: 0.2576, Validation accuracy: 0.9196
# Saving ...
#
# Epoch 128:
# Training loss: 0.4185, Training accuracy: 0.8959
# Validation loss: 0.2828, Validation accuracy: 0.9181
#
# Epoch 129:
# Training loss: 0.4359, Training accuracy: 0.8898
# Validation loss: 0.2979, Validation accuracy: 0.9157
#
# Epoch 130:
# Training loss: 0.3739, Training accuracy: 0.9080
# Validation loss: 0.2846, Validation accuracy: 0.9150
#
# Epoch 131:
# Training loss: 0.4016, Training accuracy: 0.9003
# Validation loss: 0.2735, Validation accuracy: 0.9177
#
# Epoch 132:
# Training loss: 0.3641, Training accuracy: 0.9116
# Validation loss: 0.2677, Validation accuracy: 0.9198
# Saving ...
#
# Epoch 133:
# Training loss: 0.3457, Training accuracy: 0.9199
# Validation loss: 0.2609, Validation accuracy: 0.9200
# Saving ...
#
# Epoch 134:
# Training loss: 0.3825, Training accuracy: 0.9049
# Validation loss: 0.2632, Validation accuracy: 0.9212
# Saving ...
#
# Epoch 135:
# Training loss: 0.4122, Training accuracy: 0.8978
# Validation loss: 0.2728, Validation accuracy: 0.9196
#
# Epoch 136:
# Training loss: 0.4063, Training accuracy: 0.8954
# Validation loss: 0.2698, Validation accuracy: 0.9193
#
# Epoch 137:
# Training loss: 0.3772, Training accuracy: 0.9041
# Validation loss: 0.2693, Validation accuracy: 0.9201
#
# Epoch 138:
# Training loss: 0.3565, Training accuracy: 0.9095
# Validation loss: 0.2967, Validation accuracy: 0.9183
#
# Epoch 139:
# Training loss: 0.3387, Training accuracy: 0.9196
# Validation loss: 0.2611, Validation accuracy: 0.9204
#
# Epoch 140:
# Training loss: 0.3822, Training accuracy: 0.9046
# Validation loss: 0.2740, Validation accuracy: 0.9180
#
# Epoch 141:
# Training loss: 0.4025, Training accuracy: 0.8989
# Validation loss: 0.2608, Validation accuracy: 0.9217
# Saving ...
#
# Epoch 142:
# Training loss: 0.3897, Training accuracy: 0.9028
# Validation loss: 0.2793, Validation accuracy: 0.9189
#
# Epoch 143:
# Training loss: 0.3871, Training accuracy: 0.9015
# Validation loss: 0.2819, Validation accuracy: 0.9191
#
# Epoch 144:
# Training loss: 0.4106, Training accuracy: 0.8947
# Validation loss: 0.2673, Validation accuracy: 0.9184
#
# Epoch 145:
# Training loss: 0.3981, Training accuracy: 0.8995
# Validation loss: 0.2704, Validation accuracy: 0.9193
#
# Epoch 146:
# Training loss: 0.3349, Training accuracy: 0.9178
# Validation loss: 0.2629, Validation accuracy: 0.9181
#
# Epoch 147:
# Training loss: 0.3930, Training accuracy: 0.9028
# Validation loss: 0.2700, Validation accuracy: 0.9205
#
# Epoch 148:
# Training loss: 0.3828, Training accuracy: 0.9057
# Validation loss: 0.2762, Validation accuracy: 0.9191
#
# Epoch 149:
# Training loss: 0.3591, Training accuracy: 0.9114
# Validation loss: 0.2768, Validation accuracy: 0.9210
#
# Epoch 150:
# Training loss: 0.3938, Training accuracy: 0.9011
# Validation loss: 0.2657, Validation accuracy: 0.9189
#
# Epoch 151:
# Training loss: 0.3613, Training accuracy: 0.9116
# Validation loss: 0.2789, Validation accuracy: 0.9175
#
# Epoch 152:
# Training loss: 0.3516, Training accuracy: 0.9149
# Validation loss: 0.2694, Validation accuracy: 0.9181
#
# Epoch 153:
# Training loss: 0.3838, Training accuracy: 0.9034
# Validation loss: 0.2969, Validation accuracy: 0.9205
#
# Epoch 154:
# Training loss: 0.3949, Training accuracy: 0.8987
# Validation loss: 0.2838, Validation accuracy: 0.9195
#
# Epoch 155:
# Training loss: 0.3840, Training accuracy: 0.9033
# Validation loss: 0.2726, Validation accuracy: 0.9200
#
# Epoch 156:
# Training loss: 0.3637, Training accuracy: 0.9083
# Validation loss: 0.2603, Validation accuracy: 0.9205
#
# Epoch 157:
# Training loss: 0.3868, Training accuracy: 0.9036
# Validation loss: 0.2725, Validation accuracy: 0.9184
#
# Epoch 158:
# Training loss: 0.4014, Training accuracy: 0.8995
# Validation loss: 0.2603, Validation accuracy: 0.9200
#
# Epoch 159:
# Training loss: 0.3619, Training accuracy: 0.9087
# Validation loss: 0.2893, Validation accuracy: 0.9194
#
# Current learning rate has decayed to 0.000800
# Epoch 160:
# Training loss: 0.3913, Training accuracy: 0.9024
# Validation loss: 0.2632, Validation accuracy: 0.9220
# Saving ...
#
# Epoch 161:
# Training loss: 0.3393, Training accuracy: 0.9165
# Validation loss: 0.2632, Validation accuracy: 0.9206
#
# Epoch 162:
# Training loss: 0.3450, Training accuracy: 0.9160
# Validation loss: 0.2959, Validation accuracy: 0.9193
#
# Epoch 163:
# Training loss: 0.3538, Training accuracy: 0.9136
# Validation loss: 0.2739, Validation accuracy: 0.9196
#
# Epoch 164:
# Training loss: 0.3867, Training accuracy: 0.9008
# Validation loss: 0.2614, Validation accuracy: 0.9207
#
# Epoch 165:
# Training loss: 0.3811, Training accuracy: 0.9051
# Validation loss: 0.2627, Validation accuracy: 0.9202
#
# Epoch 166:
# Training loss: 0.3930, Training accuracy: 0.9005
# Validation loss: 0.2692, Validation accuracy: 0.9200
#
# Epoch 167:
# Training loss: 0.3749, Training accuracy: 0.9064
# Validation loss: 0.2691, Validation accuracy: 0.9206
#
# Epoch 168:
# Training loss: 0.3653, Training accuracy: 0.9089
# Validation loss: 0.2636, Validation accuracy: 0.9198
#
# Epoch 169:
# Training loss: 0.4038, Training accuracy: 0.8977
# Validation loss: 0.2737, Validation accuracy: 0.9211
#
# Epoch 170:
# Training loss: 0.3892, Training accuracy: 0.9001
# Validation loss: 0.2706, Validation accuracy: 0.9207
#
# Epoch 171:
# Training loss: 0.3769, Training accuracy: 0.9053
# Validation loss: 0.2651, Validation accuracy: 0.9222
# Saving ...
#
# Epoch 172:
# Training loss: 0.3716, Training accuracy: 0.9084
# Validation loss: 0.2702, Validation accuracy: 0.9216
#
# Epoch 173:
# Training loss: 0.3676, Training accuracy: 0.9070
# Validation loss: 0.2567, Validation accuracy: 0.9219
#
# Epoch 174:
# Training loss: 0.4394, Training accuracy: 0.8865
# Validation loss: 0.2733, Validation accuracy: 0.9197
#
# Epoch 175:
# Training loss: 0.3453, Training accuracy: 0.9172
# Validation loss: 0.2751, Validation accuracy: 0.9203
#
# Epoch 176:
# Training loss: 0.4072, Training accuracy: 0.8968
# Validation loss: 0.2872, Validation accuracy: 0.9207
#
# Epoch 177:
# Training loss: 0.3111, Training accuracy: 0.9255
# Validation loss: 0.2721, Validation accuracy: 0.9200
#
# Epoch 178:
# Training loss: 0.3796, Training accuracy: 0.9080
# Validation loss: 0.2583, Validation accuracy: 0.9202
#
# Epoch 179:
# Training loss: 0.3643, Training accuracy: 0.9118
# Validation loss: 0.2543, Validation accuracy: 0.9218
#
# Epoch 180:
# Training loss: 0.3694, Training accuracy: 0.9090
# Validation loss: 0.2689, Validation accuracy: 0.9207
#
# Epoch 181:
# Training loss: 0.3697, Training accuracy: 0.9048
# Validation loss: 0.2562, Validation accuracy: 0.9220
#
# Epoch 182:
# Training loss: 0.4257, Training accuracy: 0.8913
# Validation loss: 0.2694, Validation accuracy: 0.9206
#
# Epoch 183:
# Training loss: 0.3314, Training accuracy: 0.9222
# Validation loss: 0.2658, Validation accuracy: 0.9214
#
# Epoch 184:
# Training loss: 0.3875, Training accuracy: 0.9052
# Validation loss: 0.3123, Validation accuracy: 0.9176
#
# Epoch 185:
# Training loss: 0.3844, Training accuracy: 0.9032
# Validation loss: 0.2780, Validation accuracy: 0.9209
#
# Epoch 186:
# Training loss: 0.4221, Training accuracy: 0.8961
# Validation loss: 0.2586, Validation accuracy: 0.9219
#
# Epoch 187:
# Training loss: 0.3728, Training accuracy: 0.9085
# Validation loss: 0.2741, Validation accuracy: 0.9218
#
# Epoch 188:
# Training loss: 0.3965, Training accuracy: 0.9027
# Validation loss: 0.2606, Validation accuracy: 0.9215
#
# Epoch 189:
# Training loss: 0.3706, Training accuracy: 0.9061
# Validation loss: 0.2888, Validation accuracy: 0.9199
#
# Epoch 190:
# Training loss: 0.3639, Training accuracy: 0.9133
# Validation loss: 0.2829, Validation accuracy: 0.9208
#
# Epoch 191:
# Training loss: 0.3415, Training accuracy: 0.9165
# Validation loss: 0.2598, Validation accuracy: 0.9211
#
# Epoch 192:
# Training loss: 0.3210, Training accuracy: 0.9218
# Validation loss: 0.2638, Validation accuracy: 0.9218
#
# Epoch 193:
# Training loss: 0.4031, Training accuracy: 0.9021
# Validation loss: 0.3040, Validation accuracy: 0.9192
#
# Epoch 194:
# Training loss: 0.4032, Training accuracy: 0.8998
# Validation loss: 0.2630, Validation accuracy: 0.9218
#
# Epoch 195:
# Training loss: 0.4066, Training accuracy: 0.8963
# Validation loss: 0.2928, Validation accuracy: 0.9194
#
# Epoch 196:
# Training loss: 0.3196, Training accuracy: 0.9216
# Validation loss: 0.2724, Validation accuracy: 0.9198
#
# Epoch 197:
# Training loss: 0.3250, Training accuracy: 0.9197
# Validation loss: 0.2609, Validation accuracy: 0.9203
#
# Epoch 198:
# Training loss: 0.3939, Training accuracy: 0.9026
# Validation loss: 0.2553, Validation accuracy: 0.9218
#
# Epoch 199:
# Training loss: 0.3761, Training accuracy: 0.9081
# Validation loss: 0.3008, Validation accuracy: 0.9196
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.9222 with loss: 0.2651

# %% [markdown]
# ## 4.

# %%
import matplotlib.pyplot as plt
plt.plot(range(200),train_accs,label='train_accuracy')
plt.plot(range(200),val_accs,label='validation_accuracy')
plt.xlabel('episode')
plt.ylabel('accuracy')
plt.title('Accuracy vs Episode (mixup) - alpha = 0.15')
plt.legend()
plt.show()

# %%
plt.plot(range(200),train_losses,label='train_loss')
plt.plot(range(200),val_losses,label='validation_loss')
plt.xlabel('episode')
plt.ylabel('loss')
plt.title('Loss vs Episode (mixup) - alpha = 0.15')
plt.legend()
plt.show()
