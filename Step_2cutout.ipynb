# %% [markdown]
# # Improved Regularization of Convolutional Neural Networks (Step-2cutout)

# %% [markdown]
# ## 1. Resnet-20

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F

# %%
def _weights_init(m):
    """
        Initialization of CNN weights
    """
    classname = m.__class__.__name__
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight)

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet20(nn.Module):
    def __init__(self):
        super(ResNet20, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)

        self.layer1 = self.blocks(16, 16, 3, stride=1)
        self.layer2 = self.blocks(16, 32, 3, stride=2)
        self.layer3 = self.blocks(32, 64, 3, stride=2)
        self.fc = nn.Linear(64, 10)
        self.apply(_weights_init)

    def blocks(self, in_channels, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for i in strides:
            layers.append(ResidualBlock(in_channels, out_channels, i))
            in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, out.size()[3])
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

# %% [markdown]
# ## 2. Data Processing

# %%
class Cutout(object):
    """Randomly mask out one or more patches from an image.

    Args:
        n_holes (int): Number of patches to cut out of each image.
        length (int): The length (in pixels) of each square patch.
    """
    def __init__(self, n_holes, length):
        self.n_holes = n_holes
        self.length = length

    def __call__(self, img):
        """
        Args:
            img (Tensor): Tensor image of size (C, H, W).
        Returns:
            Tensor: Image with n_holes of dimension length x length cut out of it.
        """
        h = img.size(1)
        w = img.size(2)

        mask = np.ones((h, w), np.float32)

        for n in range(self.n_holes):
            y = np.random.randint(h)
            x = np.random.randint(w)

            y1 = np.clip(y - self.length // 2, 0, h)
            y2 = np.clip(y + self.length // 2, 0, h)
            x1 = np.clip(x - self.length // 2, 0, w)
            x2 = np.clip(x + self.length // 2, 0, w)

            mask[y1: y2, x1: x2] = 0.

        mask = torch.from_numpy(mask)
        mask = mask.expand_as(img)
        img = img * mask

        return img

# %%
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader


normalize = transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],
                                     std=[0.2023, 0.1994, 0.2010])


train_loader = DataLoader(
        datasets.CIFAR10(root='./data', train=True, transform=transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.RandomCrop(32, 4),
            transforms.ToTensor(),
            normalize,
            Cutout(n_holes=2, length= 16)
            # add cutout if needed, give n_holes, length parameters according to the essay
            # n_holes = 1, length = 16 by defalt
        ]), download=True),
        batch_size=128, shuffle=True,
        num_workers=4, pin_memory=True)

val_loader = DataLoader(
        datasets.CIFAR10(root='./data', train=False, transform=transforms.Compose([
            transforms.ToTensor(),
            normalize,
        ])),
        batch_size=128, shuffle=False,
        num_workers=4, pin_memory=True)
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## 3. Model Training

# %%
import torch.optim as optim

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = ResNet20().to(device)

INITIAL_LR = 0.1
MOMENTUM = 0.9
REG = 1e-4

criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)

# %%
import os
EPOCHS = 200
DECAY_EPOCHS = [60,120,160]#decay epoch change according to essay
DECAY = 0.2

CHECKPOINT_FOLDER = "./saved_model"

best_val_acc = 0
best_val_acc_loss = 0
train_accs=[]
train_losses=[]
val_accs=[]
val_losses=[]
current_learning_rate = INITIAL_LR

print("==> Training starts!")
print("="*50)
for i in range(0, EPOCHS):
    if i in DECAY_EPOCHS:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)

    model.train()
    print("Epoch %d:" %i)
    total_examples = 0
    correct_examples = 0
    train_loss = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        outputs = model(inputs)
        loss = criterion(outputs, targets)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total_examples += targets.size(0)
        correct_examples += predicted.eq(targets).sum().item()


    avg_loss = train_loss / len(train_loader)
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
    train_accs.append(avg_acc)
    train_losses.append(avg_loss)


    model.eval()
    total_examples = 0
    correct_examples = 0

    val_loss = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item()
            _, predicted = outputs.max(1)
            total_examples += targets.size(0)
            correct_examples += predicted.eq(targets).sum().item()

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    val_accs.append(avg_acc)
    val_losses.append(avg_loss)

    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        best_val_acc_loss = avg_loss
        if not os.path.exists(CHECKPOINT_FOLDER):
            os.makedirs(CHECKPOINT_FOLDER)
        print("Saving ...")
        state = {'state_dict': model.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_FOLDER, 'cutout.pth'))

    print('')

print("="*50)
print(f"==> Optimization finished! Best validation accuracy: {best_val_acc:.4f} with loss: {best_val_acc_loss:.4f}")
# Out:
# ==> Training starts!
# ==================================================
# Epoch 0:
# Training loss: 1.8469, Training accuracy: 0.3087
# Validation loss: 1.6574, Validation accuracy: 0.4257
# Saving ...
#
# Epoch 1:
# Training loss: 1.5149, Training accuracy: 0.4428
# Validation loss: 1.7032, Validation accuracy: 0.4382
# Saving ...
#
# Epoch 2:
# Training loss: 1.3265, Training accuracy: 0.5203
# Validation loss: 1.5637, Validation accuracy: 0.4845
# Saving ...
#
# Epoch 3:
# Training loss: 1.1921, Training accuracy: 0.5729
# Validation loss: 1.1171, Validation accuracy: 0.6151
# Saving ...
#
# Epoch 4:
# Training loss: 1.1033, Training accuracy: 0.6037
# Validation loss: 1.2497, Validation accuracy: 0.6150
#
# Epoch 5:
# Training loss: 1.0431, Training accuracy: 0.6293
# Validation loss: 1.1019, Validation accuracy: 0.6366
# Saving ...
#
# Epoch 6:
# Training loss: 0.9930, Training accuracy: 0.6465
# Validation loss: 0.8411, Validation accuracy: 0.7252
# Saving ...
#
# Epoch 7:
# Training loss: 0.9403, Training accuracy: 0.6686
# Validation loss: 0.7525, Validation accuracy: 0.7539
# Saving ...
#
# Epoch 8:
# Training loss: 0.9129, Training accuracy: 0.6770
# Validation loss: 0.7570, Validation accuracy: 0.7504
#
# Epoch 9:
# Training loss: 0.8885, Training accuracy: 0.6856
# Validation loss: 0.8509, Validation accuracy: 0.7188
#
# Epoch 10:
# Training loss: 0.8596, Training accuracy: 0.6990
# Validation loss: 0.9442, Validation accuracy: 0.7048
#
# Epoch 11:
# Training loss: 0.8285, Training accuracy: 0.7090
# Validation loss: 0.6650, Validation accuracy: 0.7818
# Saving ...
#
# Epoch 12:
# Training loss: 0.8131, Training accuracy: 0.7140
# Validation loss: 0.7187, Validation accuracy: 0.7655
#
# Epoch 13:
# Training loss: 0.8031, Training accuracy: 0.7196
# Validation loss: 0.6723, Validation accuracy: 0.7762
#
# Epoch 14:
# Training loss: 0.7847, Training accuracy: 0.7237
# Validation loss: 0.8420, Validation accuracy: 0.7346
#
# Epoch 15:
# Training loss: 0.7710, Training accuracy: 0.7294
# Validation loss: 0.6501, Validation accuracy: 0.7825
# Saving ...
#
# Epoch 16:
# Training loss: 0.7614, Training accuracy: 0.7342
# Validation loss: 0.7251, Validation accuracy: 0.7692
#
# Epoch 17:
# Training loss: 0.7478, Training accuracy: 0.7371
# Validation loss: 0.8348, Validation accuracy: 0.7559
#
# Epoch 18:
# Training loss: 0.7279, Training accuracy: 0.7451
# Validation loss: 0.6552, Validation accuracy: 0.7920
# Saving ...
#
# Epoch 19:
# Training loss: 0.7240, Training accuracy: 0.7451
# Validation loss: 0.6782, Validation accuracy: 0.7798
#
# Epoch 20:
# Training loss: 0.7160, Training accuracy: 0.7472
# Validation loss: 0.5962, Validation accuracy: 0.8045
# Saving ...
#
# Epoch 21:
# Training loss: 0.7044, Training accuracy: 0.7535
# Validation loss: 0.7193, Validation accuracy: 0.7812
#
# Epoch 22:
# Training loss: 0.6999, Training accuracy: 0.7527
# Validation loss: 0.5882, Validation accuracy: 0.8080
# Saving ...
#
# Epoch 23:
# Training loss: 0.6913, Training accuracy: 0.7566
# Validation loss: 0.5650, Validation accuracy: 0.8140
# Saving ...
#
# Epoch 24:
# Training loss: 0.6917, Training accuracy: 0.7583
# Validation loss: 0.5829, Validation accuracy: 0.8102
#
# Epoch 25:
# Training loss: 0.6814, Training accuracy: 0.7584
# Validation loss: 0.7473, Validation accuracy: 0.7694
#
# Epoch 26:
# Training loss: 0.6809, Training accuracy: 0.7617
# Validation loss: 0.6063, Validation accuracy: 0.8086
#
# Epoch 27:
# Training loss: 0.6689, Training accuracy: 0.7641
# Validation loss: 0.6414, Validation accuracy: 0.7997
#
# Epoch 28:
# Training loss: 0.6689, Training accuracy: 0.7636
# Validation loss: 0.5530, Validation accuracy: 0.8259
# Saving ...
#
# Epoch 29:
# Training loss: 0.6537, Training accuracy: 0.7700
# Validation loss: 0.5339, Validation accuracy: 0.8230
#
# Epoch 30:
# Training loss: 0.6504, Training accuracy: 0.7709
# Validation loss: 0.5115, Validation accuracy: 0.8323
# Saving ...
#
# Epoch 31:
# Training loss: 0.6476, Training accuracy: 0.7733
# Validation loss: 0.5477, Validation accuracy: 0.8261
#
# Epoch 32:
# Training loss: 0.6465, Training accuracy: 0.7750
# Validation loss: 0.5368, Validation accuracy: 0.8233
#
# Epoch 33:
# Training loss: 0.6385, Training accuracy: 0.7793
# Validation loss: 0.5197, Validation accuracy: 0.8324
# Saving ...
#
# Epoch 34:
# Training loss: 0.6419, Training accuracy: 0.7772
# Validation loss: 0.5040, Validation accuracy: 0.8348
# Saving ...
#
# Epoch 35:
# Training loss: 0.6316, Training accuracy: 0.7783
# Validation loss: 0.5354, Validation accuracy: 0.8306
#
# Epoch 36:
# Training loss: 0.6314, Training accuracy: 0.7801
# Validation loss: 0.6571, Validation accuracy: 0.7971
#
# Epoch 37:
# Training loss: 0.6319, Training accuracy: 0.7789
# Validation loss: 0.5514, Validation accuracy: 0.8332
#
# Epoch 38:
# Training loss: 0.6220, Training accuracy: 0.7806
# Validation loss: 0.7260, Validation accuracy: 0.7750
#
# Epoch 39:
# Training loss: 0.6198, Training accuracy: 0.7837
# Validation loss: 0.5510, Validation accuracy: 0.8228
#
# Epoch 40:
# Training loss: 0.6212, Training accuracy: 0.7838
# Validation loss: 0.4798, Validation accuracy: 0.8390
# Saving ...
#
# Epoch 41:
# Training loss: 0.6130, Training accuracy: 0.7844
# Validation loss: 0.5129, Validation accuracy: 0.8308
#
# Epoch 42:
# Training loss: 0.6105, Training accuracy: 0.7876
# Validation loss: 0.5068, Validation accuracy: 0.8393
# Saving ...
#
# Epoch 43:
# Training loss: 0.6154, Training accuracy: 0.7866
# Validation loss: 0.4328, Validation accuracy: 0.8543
# Saving ...
#
# Epoch 44:
# Training loss: 0.6109, Training accuracy: 0.7851
# Validation loss: 0.5457, Validation accuracy: 0.8241
#
# Epoch 45:
# Training loss: 0.6057, Training accuracy: 0.7876
# Validation loss: 0.5658, Validation accuracy: 0.8260
#
# Epoch 46:
# Training loss: 0.6007, Training accuracy: 0.7908
# Validation loss: 0.6147, Validation accuracy: 0.8162
#
# Epoch 47:
# Training loss: 0.5962, Training accuracy: 0.7906
# Validation loss: 0.5216, Validation accuracy: 0.8378
#
# Epoch 48:
# Training loss: 0.6010, Training accuracy: 0.7893
# Validation loss: 0.4682, Validation accuracy: 0.8505
#
# Epoch 49:
# Training loss: 0.5951, Training accuracy: 0.7912
# Validation loss: 0.6436, Validation accuracy: 0.8054
#
# Epoch 50:
# Training loss: 0.5921, Training accuracy: 0.7911
# Validation loss: 0.5261, Validation accuracy: 0.8279
#
# Epoch 51:
# Training loss: 0.5981, Training accuracy: 0.7886
# Validation loss: 0.4648, Validation accuracy: 0.8482
#
# Epoch 52:
# Training loss: 0.5876, Training accuracy: 0.7965
# Validation loss: 0.4991, Validation accuracy: 0.8391
#
# Epoch 53:
# Training loss: 0.5873, Training accuracy: 0.7930
# Validation loss: 0.4142, Validation accuracy: 0.8612
# Saving ...
#
# Epoch 54:
# Training loss: 0.5860, Training accuracy: 0.7948
# Validation loss: 0.4784, Validation accuracy: 0.8472
#
# Epoch 55:
# Training loss: 0.5877, Training accuracy: 0.7946
# Validation loss: 0.4296, Validation accuracy: 0.8602
#
# Epoch 56:
# Training loss: 0.5788, Training accuracy: 0.7978
# Validation loss: 0.6038, Validation accuracy: 0.8166
#
# Epoch 57:
# Training loss: 0.5824, Training accuracy: 0.7949
# Validation loss: 0.5824, Validation accuracy: 0.8180
#
# Epoch 58:
# Training loss: 0.5786, Training accuracy: 0.7981
# Validation loss: 0.5720, Validation accuracy: 0.8235
#
# Epoch 59:
# Training loss: 0.5822, Training accuracy: 0.7948
# Validation loss: 0.8947, Validation accuracy: 0.7662
#
# Current learning rate has decayed to 0.020000
# Epoch 60:
# Training loss: 0.4814, Training accuracy: 0.8306
# Validation loss: 0.3151, Validation accuracy: 0.8971
# Saving ...
#
# Epoch 61:
# Training loss: 0.4566, Training accuracy: 0.8400
# Validation loss: 0.3050, Validation accuracy: 0.8975
# Saving ...
#
# Epoch 62:
# Training loss: 0.4442, Training accuracy: 0.8442
# Validation loss: 0.2970, Validation accuracy: 0.9006
# Saving ...
#
# Epoch 63:
# Training loss: 0.4354, Training accuracy: 0.8476
# Validation loss: 0.2919, Validation accuracy: 0.9024
# Saving ...
#
# Epoch 64:
# Training loss: 0.4296, Training accuracy: 0.8483
# Validation loss: 0.3040, Validation accuracy: 0.9004
#
# Epoch 65:
# Training loss: 0.4272, Training accuracy: 0.8500
# Validation loss: 0.2963, Validation accuracy: 0.9021
#
# Epoch 66:
# Training loss: 0.4289, Training accuracy: 0.8493
# Validation loss: 0.2924, Validation accuracy: 0.9052
# Saving ...
#
# Epoch 67:
# Training loss: 0.4272, Training accuracy: 0.8507
# Validation loss: 0.2873, Validation accuracy: 0.9032
#
# Epoch 68:
# Training loss: 0.4179, Training accuracy: 0.8547
# Validation loss: 0.2955, Validation accuracy: 0.9025
#
# Epoch 69:
# Training loss: 0.4205, Training accuracy: 0.8514
# Validation loss: 0.2891, Validation accuracy: 0.9049
#
# Epoch 70:
# Training loss: 0.4167, Training accuracy: 0.8525
# Validation loss: 0.2971, Validation accuracy: 0.9025
#
# Epoch 71:
# Training loss: 0.4150, Training accuracy: 0.8530
# Validation loss: 0.2930, Validation accuracy: 0.9024
#
# Epoch 72:
# Training loss: 0.4140, Training accuracy: 0.8554
# Validation loss: 0.2928, Validation accuracy: 0.9036
#
# Epoch 73:
# Training loss: 0.4146, Training accuracy: 0.8560
# Validation loss: 0.2925, Validation accuracy: 0.9051
#
# Epoch 74:
# Training loss: 0.4098, Training accuracy: 0.8573
# Validation loss: 0.2915, Validation accuracy: 0.9060
# Saving ...
#
# Epoch 75:
# Training loss: 0.4069, Training accuracy: 0.8574
# Validation loss: 0.2835, Validation accuracy: 0.9099
# Saving ...
#
# Epoch 76:
# Training loss: 0.4102, Training accuracy: 0.8560
# Validation loss: 0.2926, Validation accuracy: 0.9082
#
# Epoch 77:
# Training loss: 0.4068, Training accuracy: 0.8562
# Validation loss: 0.3009, Validation accuracy: 0.9031
#
# Epoch 78:
# Training loss: 0.4075, Training accuracy: 0.8575
# Validation loss: 0.3035, Validation accuracy: 0.9028
#
# Epoch 79:
# Training loss: 0.4042, Training accuracy: 0.8589
# Validation loss: 0.3075, Validation accuracy: 0.9003
#
# Epoch 80:
# Training loss: 0.4021, Training accuracy: 0.8584
# Validation loss: 0.2824, Validation accuracy: 0.9057
#
# Epoch 81:
# Training loss: 0.4102, Training accuracy: 0.8562
# Validation loss: 0.2942, Validation accuracy: 0.9034
#
# Epoch 82:
# Training loss: 0.4056, Training accuracy: 0.8571
# Validation loss: 0.2836, Validation accuracy: 0.9059
#
# Epoch 83:
# Training loss: 0.4053, Training accuracy: 0.8589
# Validation loss: 0.3031, Validation accuracy: 0.9019
#
# Epoch 84:
# Training loss: 0.3998, Training accuracy: 0.8591
# Validation loss: 0.2925, Validation accuracy: 0.9019
#
# Epoch 85:
# Training loss: 0.4035, Training accuracy: 0.8578
# Validation loss: 0.3100, Validation accuracy: 0.9012
#
# Epoch 86:
# Training loss: 0.3982, Training accuracy: 0.8590
# Validation loss: 0.2981, Validation accuracy: 0.9001
#
# Epoch 87:
# Training loss: 0.4039, Training accuracy: 0.8590
# Validation loss: 0.3110, Validation accuracy: 0.8992
#
# Epoch 88:
# Training loss: 0.3980, Training accuracy: 0.8586
# Validation loss: 0.3144, Validation accuracy: 0.8963
#
# Epoch 89:
# Training loss: 0.4013, Training accuracy: 0.8578
# Validation loss: 0.3412, Validation accuracy: 0.8901
#
# Epoch 90:
# Training loss: 0.3960, Training accuracy: 0.8617
# Validation loss: 0.3051, Validation accuracy: 0.8986
#
# Epoch 91:
# Training loss: 0.3999, Training accuracy: 0.8598
# Validation loss: 0.2970, Validation accuracy: 0.9058
#
# Epoch 92:
# Training loss: 0.4014, Training accuracy: 0.8596
# Validation loss: 0.3146, Validation accuracy: 0.8999
#
# Epoch 93:
# Training loss: 0.3971, Training accuracy: 0.8612
# Validation loss: 0.3349, Validation accuracy: 0.8959
#
# Epoch 94:
# Training loss: 0.3966, Training accuracy: 0.8598
# Validation loss: 0.3068, Validation accuracy: 0.9013
#
# Epoch 95:
# Training loss: 0.4005, Training accuracy: 0.8589
# Validation loss: 0.3024, Validation accuracy: 0.9020
#
# Epoch 96:
# Training loss: 0.3974, Training accuracy: 0.8602
# Validation loss: 0.3209, Validation accuracy: 0.8984
#
# Epoch 97:
# Training loss: 0.3975, Training accuracy: 0.8590
# Validation loss: 0.3049, Validation accuracy: 0.9038
#
# Epoch 98:
# Training loss: 0.4019, Training accuracy: 0.8591
# Validation loss: 0.3372, Validation accuracy: 0.8926
#
# Epoch 99:
# Training loss: 0.3982, Training accuracy: 0.8599
# Validation loss: 0.3010, Validation accuracy: 0.9033
#
# Epoch 100:
# Training loss: 0.3972, Training accuracy: 0.8613
# Validation loss: 0.2975, Validation accuracy: 0.9047
#
# Epoch 101:
# Training loss: 0.3986, Training accuracy: 0.8604
# Validation loss: 0.3139, Validation accuracy: 0.8973
#
# Epoch 102:
# Training loss: 0.3951, Training accuracy: 0.8602
# Validation loss: 0.3137, Validation accuracy: 0.9009
#
# Epoch 103:
# Training loss: 0.3910, Training accuracy: 0.8623
# Validation loss: 0.3000, Validation accuracy: 0.9036
#
# Epoch 104:
# Training loss: 0.3964, Training accuracy: 0.8608
# Validation loss: 0.2910, Validation accuracy: 0.9061
#
# Epoch 105:
# Training loss: 0.3923, Training accuracy: 0.8620
# Validation loss: 0.3245, Validation accuracy: 0.8977
#
# Epoch 106:
# Training loss: 0.3948, Training accuracy: 0.8608
# Validation loss: 0.3360, Validation accuracy: 0.8920
#
# Epoch 107:
# Training loss: 0.3974, Training accuracy: 0.8596
# Validation loss: 0.3508, Validation accuracy: 0.8930
#
# Epoch 108:
# Training loss: 0.4026, Training accuracy: 0.8582
# Validation loss: 0.3237, Validation accuracy: 0.9014
#
# Epoch 109:
# Training loss: 0.3926, Training accuracy: 0.8614
# Validation loss: 0.3125, Validation accuracy: 0.9000
#
# Epoch 110:
# Training loss: 0.3982, Training accuracy: 0.8585
# Validation loss: 0.2913, Validation accuracy: 0.9081
#
# Epoch 111:
# Training loss: 0.3977, Training accuracy: 0.8589
# Validation loss: 0.3067, Validation accuracy: 0.9028
#
# Epoch 112:
# Training loss: 0.3964, Training accuracy: 0.8594
# Validation loss: 0.2951, Validation accuracy: 0.9059
#
# Epoch 113:
# Training loss: 0.3957, Training accuracy: 0.8607
# Validation loss: 0.3274, Validation accuracy: 0.8987
#
# Epoch 114:
# Training loss: 0.3907, Training accuracy: 0.8640
# Validation loss: 0.3072, Validation accuracy: 0.9031
#
# Epoch 115:
# Training loss: 0.3918, Training accuracy: 0.8619
# Validation loss: 0.3303, Validation accuracy: 0.8945
#
# Epoch 116:
# Training loss: 0.3944, Training accuracy: 0.8601
# Validation loss: 0.3603, Validation accuracy: 0.8863
#
# Epoch 117:
# Training loss: 0.3992, Training accuracy: 0.8591
# Validation loss: 0.3406, Validation accuracy: 0.8913
#
# Epoch 118:
# Training loss: 0.3958, Training accuracy: 0.8598
# Validation loss: 0.2933, Validation accuracy: 0.9073
#
# Epoch 119:
# Training loss: 0.3959, Training accuracy: 0.8609
# Validation loss: 0.3160, Validation accuracy: 0.9036
#
# Current learning rate has decayed to 0.004000
# Epoch 120:
# Training loss: 0.3512, Training accuracy: 0.8774
# Validation loss: 0.2548, Validation accuracy: 0.9206
# Saving ...
#
# Epoch 121:
# Training loss: 0.3314, Training accuracy: 0.8843
# Validation loss: 0.2539, Validation accuracy: 0.9188
#
# Epoch 122:
# Training loss: 0.3340, Training accuracy: 0.8818
# Validation loss: 0.2536, Validation accuracy: 0.9215
# Saving ...
#
# Epoch 123:
# Training loss: 0.3302, Training accuracy: 0.8848
# Validation loss: 0.2521, Validation accuracy: 0.9205
#
# Epoch 124:
# Training loss: 0.3325, Training accuracy: 0.8825
# Validation loss: 0.2552, Validation accuracy: 0.9199
#
# Epoch 125:
# Training loss: 0.3231, Training accuracy: 0.8858
# Validation loss: 0.2501, Validation accuracy: 0.9215
#
# Epoch 126:
# Training loss: 0.3238, Training accuracy: 0.8868
# Validation loss: 0.2533, Validation accuracy: 0.9194
#
# Epoch 127:
# Training loss: 0.3264, Training accuracy: 0.8831
# Validation loss: 0.2498, Validation accuracy: 0.9223
# Saving ...
#
# Epoch 128:
# Training loss: 0.3156, Training accuracy: 0.8887
# Validation loss: 0.2516, Validation accuracy: 0.9213
#
# Epoch 129:
# Training loss: 0.3211, Training accuracy: 0.8875
# Validation loss: 0.2500, Validation accuracy: 0.9211
#
# Epoch 130:
# Training loss: 0.3177, Training accuracy: 0.8890
# Validation loss: 0.2531, Validation accuracy: 0.9222
#
# Epoch 131:
# Training loss: 0.3180, Training accuracy: 0.8862
# Validation loss: 0.2515, Validation accuracy: 0.9225
# Saving ...
#
# Epoch 132:
# Training loss: 0.3206, Training accuracy: 0.8871
# Validation loss: 0.2505, Validation accuracy: 0.9229
# Saving ...
#
# Epoch 133:
# Training loss: 0.3173, Training accuracy: 0.8891
# Validation loss: 0.2551, Validation accuracy: 0.9209
#
# Epoch 134:
# Training loss: 0.3133, Training accuracy: 0.8884
# Validation loss: 0.2525, Validation accuracy: 0.9234
# Saving ...
#
# Epoch 135:
# Training loss: 0.3120, Training accuracy: 0.8909
# Validation loss: 0.2524, Validation accuracy: 0.9229
#
# Epoch 136:
# Training loss: 0.3145, Training accuracy: 0.8880
# Validation loss: 0.2525, Validation accuracy: 0.9236
# Saving ...
#
# Epoch 137:
# Training loss: 0.3087, Training accuracy: 0.8896
# Validation loss: 0.2593, Validation accuracy: 0.9229
#
# Epoch 138:
# Training loss: 0.3171, Training accuracy: 0.8884
# Validation loss: 0.2546, Validation accuracy: 0.9229
#
# Epoch 139:
# Training loss: 0.3126, Training accuracy: 0.8904
# Validation loss: 0.2542, Validation accuracy: 0.9205
#
# Epoch 140:
# Training loss: 0.3097, Training accuracy: 0.8920
# Validation loss: 0.2494, Validation accuracy: 0.9224
#
# Epoch 141:
# Training loss: 0.3095, Training accuracy: 0.8890
# Validation loss: 0.2499, Validation accuracy: 0.9258
# Saving ...
#
# Epoch 142:
# Training loss: 0.3110, Training accuracy: 0.8890
# Validation loss: 0.2507, Validation accuracy: 0.9254
#
# Epoch 143:
# Training loss: 0.3094, Training accuracy: 0.8922
# Validation loss: 0.2596, Validation accuracy: 0.9213
#
# Epoch 144:
# Training loss: 0.3086, Training accuracy: 0.8891
# Validation loss: 0.2528, Validation accuracy: 0.9239
#
# Epoch 145:
# Training loss: 0.3118, Training accuracy: 0.8903
# Validation loss: 0.2575, Validation accuracy: 0.9207
#
# Epoch 146:
# Training loss: 0.3092, Training accuracy: 0.8908
# Validation loss: 0.2481, Validation accuracy: 0.9240
#
# Epoch 147:
# Training loss: 0.3075, Training accuracy: 0.8926
# Validation loss: 0.2573, Validation accuracy: 0.9236
#
# Epoch 148:
# Training loss: 0.3083, Training accuracy: 0.8908
# Validation loss: 0.2504, Validation accuracy: 0.9228
#
# Epoch 149:
# Training loss: 0.3073, Training accuracy: 0.8907
# Validation loss: 0.2504, Validation accuracy: 0.9233
#
# Epoch 150:
# Training loss: 0.3070, Training accuracy: 0.8920
# Validation loss: 0.2586, Validation accuracy: 0.9197
#
# Epoch 151:
# Training loss: 0.3063, Training accuracy: 0.8923
# Validation loss: 0.2594, Validation accuracy: 0.9221
#
# Epoch 152:
# Training loss: 0.3043, Training accuracy: 0.8917
# Validation loss: 0.2618, Validation accuracy: 0.9234
#
# Epoch 153:
# Training loss: 0.3073, Training accuracy: 0.8899
# Validation loss: 0.2574, Validation accuracy: 0.9204
#
# Epoch 154:
# Training loss: 0.3022, Training accuracy: 0.8930
# Validation loss: 0.2474, Validation accuracy: 0.9259
# Saving ...
#
# Epoch 155:
# Training loss: 0.3060, Training accuracy: 0.8923
# Validation loss: 0.2509, Validation accuracy: 0.9240
#
# Epoch 156:
# Training loss: 0.3037, Training accuracy: 0.8921
# Validation loss: 0.2496, Validation accuracy: 0.9236
#
# Epoch 157:
# Training loss: 0.3061, Training accuracy: 0.8914
# Validation loss: 0.2575, Validation accuracy: 0.9218
#
# Epoch 158:
# Training loss: 0.3082, Training accuracy: 0.8900
# Validation loss: 0.2552, Validation accuracy: 0.9228
#
# Epoch 159:
# Training loss: 0.3026, Training accuracy: 0.8927
# Validation loss: 0.2624, Validation accuracy: 0.9217
#
# Current learning rate has decayed to 0.000800
# Epoch 160:
# Training loss: 0.2949, Training accuracy: 0.8949
# Validation loss: 0.2479, Validation accuracy: 0.9255
#
# Epoch 161:
# Training loss: 0.2883, Training accuracy: 0.8975
# Validation loss: 0.2483, Validation accuracy: 0.9255
#
# Epoch 162:
# Training loss: 0.2905, Training accuracy: 0.8975
# Validation loss: 0.2480, Validation accuracy: 0.9251
#
# Epoch 163:
# Training loss: 0.2904, Training accuracy: 0.8982
# Validation loss: 0.2478, Validation accuracy: 0.9250
#
# Epoch 164:
# Training loss: 0.2956, Training accuracy: 0.8958
# Validation loss: 0.2449, Validation accuracy: 0.9262
# Saving ...
#
# Epoch 165:
# Training loss: 0.2853, Training accuracy: 0.8994
# Validation loss: 0.2445, Validation accuracy: 0.9270
# Saving ...
#
# Epoch 166:
# Training loss: 0.2923, Training accuracy: 0.8971
# Validation loss: 0.2455, Validation accuracy: 0.9263
#
# Epoch 167:
# Training loss: 0.2851, Training accuracy: 0.8983
# Validation loss: 0.2452, Validation accuracy: 0.9274
# Saving ...
#
# Epoch 168:
# Training loss: 0.2861, Training accuracy: 0.8973
# Validation loss: 0.2466, Validation accuracy: 0.9244
#
# Epoch 169:
# Training loss: 0.2846, Training accuracy: 0.8997
# Validation loss: 0.2454, Validation accuracy: 0.9258
#
# Epoch 170:
# Training loss: 0.2838, Training accuracy: 0.8984
# Validation loss: 0.2470, Validation accuracy: 0.9247
#
# Epoch 171:
# Training loss: 0.2870, Training accuracy: 0.8983
# Validation loss: 0.2453, Validation accuracy: 0.9259
#
# Epoch 172:
# Training loss: 0.2868, Training accuracy: 0.8981
# Validation loss: 0.2460, Validation accuracy: 0.9262
#
# Epoch 173:
# Training loss: 0.2881, Training accuracy: 0.8986
# Validation loss: 0.2460, Validation accuracy: 0.9266
#
# Epoch 174:
# Training loss: 0.2860, Training accuracy: 0.8988
# Validation loss: 0.2452, Validation accuracy: 0.9264
#
# Epoch 175:
# Training loss: 0.2820, Training accuracy: 0.9018
# Validation loss: 0.2462, Validation accuracy: 0.9239
#
# Epoch 176:
# Training loss: 0.2868, Training accuracy: 0.8984
# Validation loss: 0.2469, Validation accuracy: 0.9251
#
# Epoch 177:
# Training loss: 0.2844, Training accuracy: 0.8995
# Validation loss: 0.2456, Validation accuracy: 0.9260
#
# Epoch 178:
# Training loss: 0.2822, Training accuracy: 0.9005
# Validation loss: 0.2457, Validation accuracy: 0.9264
#
# Epoch 179:
# Training loss: 0.2886, Training accuracy: 0.8982
# Validation loss: 0.2459, Validation accuracy: 0.9251
#
# Epoch 180:
# Training loss: 0.2873, Training accuracy: 0.8978
# Validation loss: 0.2444, Validation accuracy: 0.9262
#
# Epoch 181:
# Training loss: 0.2853, Training accuracy: 0.8984
# Validation loss: 0.2472, Validation accuracy: 0.9264
#
# Epoch 182:
# Training loss: 0.2840, Training accuracy: 0.8997
# Validation loss: 0.2461, Validation accuracy: 0.9243
#
# Epoch 183:
# Training loss: 0.2819, Training accuracy: 0.8996
# Validation loss: 0.2447, Validation accuracy: 0.9264
#
# Epoch 184:
# Training loss: 0.2832, Training accuracy: 0.9003
# Validation loss: 0.2445, Validation accuracy: 0.9255
#
# Epoch 185:
# Training loss: 0.2808, Training accuracy: 0.9003
# Validation loss: 0.2454, Validation accuracy: 0.9264
#
# Epoch 186:
# Training loss: 0.2846, Training accuracy: 0.9004
# Validation loss: 0.2481, Validation accuracy: 0.9272
#
# Epoch 187:
# Training loss: 0.2802, Training accuracy: 0.9008
# Validation loss: 0.2433, Validation accuracy: 0.9275
# Saving ...
#
# Epoch 188:
# Training loss: 0.2858, Training accuracy: 0.9000
# Validation loss: 0.2454, Validation accuracy: 0.9275
#
# Epoch 189:
# Training loss: 0.2792, Training accuracy: 0.9014
# Validation loss: 0.2436, Validation accuracy: 0.9273
#
# Epoch 190:
# Training loss: 0.2824, Training accuracy: 0.8998
# Validation loss: 0.2429, Validation accuracy: 0.9264
#
# Epoch 191:
# Training loss: 0.2846, Training accuracy: 0.8997
# Validation loss: 0.2451, Validation accuracy: 0.9261
#
# Epoch 192:
# Training loss: 0.2816, Training accuracy: 0.8993
# Validation loss: 0.2421, Validation accuracy: 0.9262
#
# Epoch 193:
# Training loss: 0.2870, Training accuracy: 0.8979
# Validation loss: 0.2431, Validation accuracy: 0.9260
#
# Epoch 194:
# Training loss: 0.2811, Training accuracy: 0.9008
# Validation loss: 0.2450, Validation accuracy: 0.9272
#
# Epoch 195:
# Training loss: 0.2749, Training accuracy: 0.9037
# Validation loss: 0.2412, Validation accuracy: 0.9266
#
# Epoch 196:
# Training loss: 0.2815, Training accuracy: 0.9012
# Validation loss: 0.2460, Validation accuracy: 0.9259
#
# Epoch 197:
# Training loss: 0.2828, Training accuracy: 0.9003
# Validation loss: 0.2436, Validation accuracy: 0.9266
#
# Epoch 198:
# Training loss: 0.2791, Training accuracy: 0.9011
# Validation loss: 0.2437, Validation accuracy: 0.9267
#
# Epoch 199:
# Training loss: 0.2846, Training accuracy: 0.8998
# Validation loss: 0.2451, Validation accuracy: 0.9266
#
# ==================================================
# ==> Optimization finished! Best validation accuracy: 0.9275 with loss: 0.2433

# %% [markdown]
# ## 4.

# %%
import matplotlib.pyplot as plt
plt.plot(range(200),train_accs,label='train_accuracy')
plt.plot(range(200),val_accs,label='validation_accuracy')
plt.xlabel('episode')
plt.ylabel('accuracy')
plt.title('Accuracy vs Episode (cutout) - n_holes=2, length=16')
plt.legend()
plt.show()

# %%
plt.plot(range(200),train_losses,label='train_loss')
plt.plot(range(200),val_losses,label='validation_loss')
plt.xlabel('episode')
plt.ylabel('loss')
plt.title('Loss vs Episode (cutout) - n_holes=2, length=16')
plt.legend()
plt.show()
